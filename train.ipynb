# %%
# pretrained weight 모델을 다운로드 받기 위해서 mmdetection/checkpoints 디렉토리를 만듬. 
#!cd mmdetection; mkdir checkpoints

# %%
#!wget -O /content/mmdetection/checkpoints/mask_rcnn_r101_fpn_1x_coco_20200204-1efe0ed5.pth http://download.openmmlab.com/mmdetection/v2.0/mask_rcnn/mask_rcnn_r101_fpn_1x_coco/mask_rcnn_r101_fpn_1x_coco_20200204-1efe0ed5.pth

# %%
#!ls -lia /content/mmdetection/checkpoints

# %%
import torch
from mmdet.apis import init_detector, inference_detector
import mmcv


print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.9.0+cu111 (GeForce RTX 3070)

# %%
# config 파일을 설정하고, 다운로드 받은 pretrained 모델을 checkpoint로 설정. 
config_file = 'configs/mask_rcnn/mask_rcnn_r50_fpn_1x_coco.py'
checkpoint_file = 'checkpoints/mask_rcnn_r50_fpn_1x_coco_20200205-d4b0c5d6.pth'

# %%
from mmdet.datasets.builder import DATASETS
from mmdet.datasets.coco import CocoDataset

@DATASETS.register_module(force=True)
class NucleusDataset(CocoDataset):
  CLASSES = ['body', 'right_hand', 'left_hand', 'left_foot', 'right_foot', 'right_thigh', 'left_thigh', 'right_calf', 'left_calf', 
     'left_arm', 'right_arm', 'left_forearm',  'right_forearm' , 'head']

# %%
from mmcv import Config

cfg = Config.fromfile(config_file)

# %%
from mmdet.apis import set_random_seed

# dataset에 대한 환경 파라미터 수정. 
cfg.dataset_type = 'NucleusDataset' # 'NucleusDataset'
cfg.data_root = '/home/seonghwan/PyTorch-Simple-MaskRCNN/heroes_data/train_dataset' #'/content/coco_output/'

# train, val, test dataset에 대한 type, data_root, ann_file, img_prefix 환경 파라미터 수정. 
cfg.data.train.type =  'NucleusDataset' #'NucleusDataset'
cfg.data.train.data_root = '/home/seonghwan/PyTorch-Simple-MaskRCNN/heroes_data/train_dataset/' #'/content/coco_output/'
cfg.data.train.ann_file = 'new_ai_2014_train=mask.json' #'train_coco.json'
cfg.data.train.img_prefix = '2014_train=mask'

cfg.data.val.type = 'NucleusDataset' # 'NucleusDataset'
cfg.data.val.data_root = '/home/seonghwan/PyTorch-Simple-MaskRCNN/heroes_data/train_dataset/'#'/content/coco_output/'
cfg.data.val.ann_file ='new_ai_2014_val=mask.json' # 'val_coco.json'
cfg.data.val.img_prefix = '2014_val=mask'

# class의 갯수 수정. 
cfg.model.roi_head.bbox_head.num_classes = 14 # 1
cfg.model.roi_head.mask_head.num_classes = 14 # 1

# pretrained 모델
cfg.load_from = 'checkpoints/mask_rcnn_r50_fpn_1x_coco_20200205-d4b0c5d6.pth' #'/content/mmdetection/checkpoints/mask_rcnn_r101_fpn_1x_coco_20200204-1efe0ed5.pth'

# 학습 weight 파일로 로그를 저장하기 위한 디렉토리 설정. 
cfg.work_dir = './tutorial_exps'

# 학습율 변경 환경 파라미터 설정. 
cfg.optimizer.lr = 0.02 / 8
cfg.lr_config.warmup = None
cfg.log_config.interval = 10

# CocoDataset의 경우 metric을 bbox로 설정해야 함.(mAP아님. bbox로 설정하면 mAP를 iou threshold를 0.5 ~ 0.95까지 변경하면서 측정)
cfg.evaluation.metric = ['bbox', 'segm']
cfg.evaluation.interval = 12
cfg.checkpoint_config.interval = 12

# epochs 횟수는 36으로 증가 
cfg.runner.max_epochs = 3 

# 두번 config를 로드하면 lr_config의 policy가 사라지는 오류로 인하여 설정. 
cfg.lr_config.policy='step'
# Set seed thus the results are more reproducible
cfg.seed = 0
set_random_seed(0, deterministic=False)
cfg.gpu_ids = range(1)

# %%
from mmdet.datasets import build_dataset
from mmdet.models import build_detector
from mmdet.apis import train_detector

# train, valid 용 Dataset 생성. 
datasets_train = [build_dataset(cfg.data.train)]
datasets_val = [build_dataset(cfg.data.val)]
# Out:
# loading annotations into memory...
# Done (t=11.75s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.58s)
# creating index...
# index created!

# %%
datasets_train
# Out:
# [
#  NucleusDataset Train dataset with number of images 26437, and instance counts:
#  +-----------------+-------+-------------------+-------+--------------------+-------+---------------+-------+----------------+-------+
#  | category        | count | category          | count | category           | count | category      | count | category       | count |
#  +-----------------+-------+-------------------+-------+--------------------+-------+---------------+-------+----------------+-------+
#  | 0 [body]        | 50719 | 1 [right_hand]    | 29174 | 2 [left_hand]      | 28062 | 3 [left_foot] | 16352 | 4 [right_foot] | 16334 |
#  | 5 [right_thigh] | 28932 | 6 [left_thigh]    | 28546 | 7 [right_calf]     | 21459 | 8 [left_calf] | 21481 | 9 [left_arm]   | 30559 |
#  | 10 [right_arm]  | 31574 | 11 [left_forearm] | 29023 | 12 [right_forearm] | 30216 | 13 [head]     | 38272 | -1 background  | 0     |
#  +-----------------+-------+-------------------+-------+--------------------+-------+---------------+-------+----------------+-------+]

# %%
print(datasets_train[0])
print(datasets_val[0])
# Out:
# NucleusDataset Train dataset with number of images 26437, and instance counts:
# +-----------------+-------+-------------------+-------+--------------------+-------+---------------+-------+----------------+-------+
# | category        | count | category          | count | category           | count | category      | count | category       | count |
# +-----------------+-------+-------------------+-------+--------------------+-------+---------------+-------+----------------+-------+
# | 0 [body]        | 50719 | 1 [right_hand]    | 29174 | 2 [left_hand]      | 28062 | 3 [left_foot] | 16352 | 4 [right_foot] | 16334 |
# | 5 [right_thigh] | 28932 | 6 [left_thigh]    | 28546 | 7 [right_calf]     | 21459 | 8 [left_calf] | 21481 | 9 [left_arm]   | 30559 |
# | 10 [right_arm]  | 31574 | 11 [left_forearm] | 29023 | 12 [right_forearm] | 30216 | 13 [head]     | 38272 | -1 background  | 0     |
# +-----------------+-------+-------------------+-------+--------------------+-------+---------------+-------+----------------+-------+
#
# NucleusDataset Train dataset with number of images 1508, and instance counts:
# +-----------------+-------+-------------------+-------+--------------------+-------+---------------+-------+----------------+-------+
# | category        | count | category          | count | category           | count | category      | count | category       | count |
# +-----------------+-------+-------------------+-------+--------------------+-------+---------------+-------+----------------+-------+
# | 0 [body]        | 2967  | 1 [right_hand]    | 1661  | 2 [left_hand]      | 1596  | 3 [left_foot] | 912   | 4 [right_foot] | 919   |
# | 5 [right_thigh] | 1643  | 6 [left_thigh]    | 1625  | 7 [right_calf]     | 1205  | 8 [left_calf] | 1198  | 9 [left_arm]   | 1714  |
# | 10 [right_arm]  | 1805  | 11 [left_forearm] | 1631  | 12 [right_forearm] | 1726  | 13 [head]     | 2188  | -1 background  | 0     |
# +-----------------+-------+-------------------+-------+--------------------+-------+---------------+-------+----------------+-------+

# %%
model = build_detector(cfg.model, train_cfg=cfg.get('train_cfg'), test_cfg=cfg.get('test_cfg'))
model.CLASSES = datasets_train[0].CLASSES
print(model.CLASSES)
# Out:
# ['body', 'right_hand', 'left_hand', 'left_foot', 'right_foot', 'right_thigh', 'left_thigh', 'right_calf', 'left_calf', 'left_arm', 'right_arm', 'left_forearm', 'right_forearm', 'head']

# %%
import mmcv
import os.path as osp
mmcv.mkdir_or_exist(osp.abspath(cfg.work_dir))
# epochs는 config의 runner 파라미터로 지정됨. 기본 12회 
train_detector(model, datasets_train, cfg, distributed=False, validate=True)
# Out:
# loading annotations into memory...
# 2021-11-22 18:30:40,301 - mmdet - INFO - load checkpoint from local path: checkpoints/mask_rcnn_r50_fpn_1x_coco_20200205-d4b0c5d6.pth
# Done (t=0.35s)
# creating index...
# index created!
# 2021-11-22 18:30:41,503 - mmdet - WARNING - The model and loaded state dict do not match exactly
#
# size mismatch for roi_head.bbox_head.fc_cls.weight: copying a param with shape torch.Size([81, 1024]) from checkpoint, the shape in current model is torch.Size([15, 1024]).
# size mismatch for roi_head.bbox_head.fc_cls.bias: copying a param with shape torch.Size([81]) from checkpoint, the shape in current model is torch.Size([15]).
# size mismatch for roi_head.bbox_head.fc_reg.weight: copying a param with shape torch.Size([320, 1024]) from checkpoint, the shape in current model is torch.Size([56, 1024]).
# size mismatch for roi_head.bbox_head.fc_reg.bias: copying a param with shape torch.Size([320]) from checkpoint, the shape in current model is torch.Size([56]).
# size mismatch for roi_head.mask_head.conv_logits.weight: copying a param with shape torch.Size([80, 256, 1, 1]) from checkpoint, the shape in current model is torch.Size([14, 256, 1, 1]).
# size mismatch for roi_head.mask_head.conv_logits.bias: copying a param with shape torch.Size([80]) from checkpoint, the shape in current model is torch.Size([14]).
# 2021-11-22 18:30:41,505 - mmdet - INFO - Start running, host: seonghwan@seonghwan-desktop, work_dir: /home/seonghwan/mmdetection/tutorial_exps
# 2021-11-22 18:30:41,505 - mmdet - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) StepLrUpdaterHook
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) StepLrUpdaterHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
#  --------------------
# after_train_iter:
# (ABOVE_NORMAL) OptimizerHook
# (NORMAL      ) CheckpointHook
# (LOW         ) IterTimerHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) CheckpointHook
# (LOW         ) EvalHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) NumClassCheckHook
# (LOW         ) IterTimerHook
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# before_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_iter:
# (LOW         ) IterTimerHook
#  --------------------
# after_val_epoch:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# after_run:
# (VERY_LOW    ) TextLoggerHook
#  --------------------
# 2021-11-22 18:30:41,506 - mmdet - INFO - workflow: [('train', 1)], max: 3 epochs
# 2021-11-22 18:30:41,506 - mmdet - INFO - Checkpoints will be saved to /home/seonghwan/mmdetection/tutorial_exps by HardDiskBackend.
# /home/seonghwan/anaconda3/envs/mask_rcnn_ver2/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# 2021-11-22 18:30:48,202 - mmdet - INFO - Epoch [1][10/13219]	lr: 2.500e-03, eta: 7:19:06, time: 0.665, data_time: 0.272, memory: 3813, loss_rpn_cls: 0.4091, loss_rpn_bbox: 0.1233, loss_cls: 1.5099, acc: 68.1934, loss_bbox: 0.5163, loss_mask: 0.7047, loss: 3.2632
# 2021-11-22 18:30:51,774 - mmdet - INFO - Epoch [1][20/13219]	lr: 2.500e-03, eta: 5:37:26, time: 0.357, data_time: 0.045, memory: 3826, loss_rpn_cls: 0.1401, loss_rpn_bbox: 0.0988, loss_cls: 0.9461, acc: 80.9375, loss_bbox: 0.6961, loss_mask: 0.6664, loss: 2.5475
# 2021-11-22 18:30:55,460 - mmdet - INFO - Epoch [1][30/13219]	lr: 2.500e-03, eta: 5:06:03, time: 0.369, data_time: 0.048, memory: 4021, loss_rpn_cls: 0.1777, loss_rpn_bbox: 0.1153, loss_cls: 0.9475, acc: 79.6680, loss_bbox: 0.7050, loss_mask: 0.6398, loss: 2.5853
# 2021-11-22 18:30:58,897 - mmdet - INFO - Epoch [1][40/13219]	lr: 2.500e-03, eta: 4:46:11, time: 0.344, data_time: 0.037, memory: 4021, loss_rpn_cls: 0.1492, loss_rpn_bbox: 0.1026, loss_cls: 0.9559, acc: 79.3945, loss_bbox: 0.7084, loss_mask: 0.6062, loss: 2.5224
# 2021-11-22 18:31:02,356 - mmdet - INFO - Epoch [1][50/13219]	lr: 2.500e-03, eta: 4:34:38, time: 0.346, data_time: 0.036, memory: 4021, loss_rpn_cls: 0.1194, loss_rpn_bbox: 0.0837, loss_cls: 0.9273, acc: 78.8965, loss_bbox: 0.7489, loss_mask: 0.5320, loss: 2.4113
# 2021-11-22 18:31:05,897 - mmdet - INFO - Epoch [1][60/13219]	lr: 2.500e-03, eta: 4:27:42, time: 0.354, data_time: 0.038, memory: 4021, loss_rpn_cls: 0.1495, loss_rpn_bbox: 0.1153, loss_cls: 0.9590, acc: 78.7695, loss_bbox: 0.7395, loss_mask: 0.4885, loss: 2.4519
# 2021-11-22 18:31:09,276 - mmdet - INFO - Epoch [1][70/13219]	lr: 2.500e-03, eta: 4:21:15, time: 0.338, data_time: 0.031, memory: 4021, loss_rpn_cls: 0.1271, loss_rpn_bbox: 0.0915, loss_cls: 0.8780, acc: 79.6094, loss_bbox: 0.6914, loss_mask: 0.4216, loss: 2.2096
# 2021-11-22 18:31:12,934 - mmdet - INFO - Epoch [1][80/13219]	lr: 2.500e-03, eta: 4:18:42, time: 0.366, data_time: 0.045, memory: 4155, loss_rpn_cls: 0.1309, loss_rpn_bbox: 0.1078, loss_cls: 0.8626, acc: 79.3555, loss_bbox: 0.6976, loss_mask: 0.4162, loss: 2.2151
# 2021-11-22 18:31:16,351 - mmdet - INFO - Epoch [1][90/13219]	lr: 2.500e-03, eta: 4:14:56, time: 0.342, data_time: 0.036, memory: 4155, loss_rpn_cls: 0.0947, loss_rpn_bbox: 0.0906, loss_cls: 0.8323, acc: 79.7949, loss_bbox: 0.7074, loss_mask: 0.4123, loss: 2.1372
# 2021-11-22 18:31:19,839 - mmdet - INFO - Epoch [1][100/13219]	lr: 2.500e-03, eta: 4:12:23, time: 0.349, data_time: 0.040, memory: 4155, loss_rpn_cls: 0.0924, loss_rpn_bbox: 0.0870, loss_cls: 0.8557, acc: 79.4922, loss_bbox: 0.7427, loss_mask: 0.3917, loss: 2.1694
# 2021-11-22 18:31:23,422 - mmdet - INFO - Epoch [1][110/13219]	lr: 2.500e-03, eta: 4:10:50, time: 0.358, data_time: 0.041, memory: 4182, loss_rpn_cls: 0.1641, loss_rpn_bbox: 0.1028, loss_cls: 0.8694, acc: 79.5508, loss_bbox: 0.7391, loss_mask: 0.4256, loss: 2.3011
# 2021-11-22 18:31:26,811 - mmdet - INFO - Epoch [1][120/13219]	lr: 2.500e-03, eta: 4:08:31, time: 0.339, data_time: 0.031, memory: 4182, loss_rpn_cls: 0.1140, loss_rpn_bbox: 0.0868, loss_cls: 0.8375, acc: 79.1113, loss_bbox: 0.7329, loss_mask: 0.4051, loss: 2.1762
# 2021-11-22 18:31:30,156 - mmdet - INFO - Epoch [1][130/13219]	lr: 2.500e-03, eta: 4:06:16, time: 0.334, data_time: 0.028, memory: 4182, loss_rpn_cls: 0.0876, loss_rpn_bbox: 0.0827, loss_cls: 0.7812, acc: 80.4492, loss_bbox: 0.6936, loss_mask: 0.4096, loss: 2.0547
# 2021-11-22 18:31:33,774 - mmdet - INFO - Epoch [1][140/13219]	lr: 2.500e-03, eta: 4:05:38, time: 0.362, data_time: 0.041, memory: 4182, loss_rpn_cls: 0.0825, loss_rpn_bbox: 0.1036, loss_cls: 0.8687, acc: 77.8125, loss_bbox: 0.7872, loss_mask: 0.4108, loss: 2.2528
# 2021-11-22 18:31:37,257 - mmdet - INFO - Epoch [1][150/13219]	lr: 2.500e-03, eta: 4:04:30, time: 0.348, data_time: 0.039, memory: 4182, loss_rpn_cls: 0.1092, loss_rpn_bbox: 0.1067, loss_cls: 0.7356, acc: 81.0547, loss_bbox: 0.6520, loss_mask: 0.3901, loss: 1.9936
# 2021-11-22 18:31:40,818 - mmdet - INFO - Epoch [1][160/13219]	lr: 2.500e-03, eta: 4:03:48, time: 0.356, data_time: 0.042, memory: 4182, loss_rpn_cls: 0.1229, loss_rpn_bbox: 0.1078, loss_cls: 0.7416, acc: 81.0156, loss_bbox: 0.6438, loss_mask: 0.3942, loss: 2.0103
# 2021-11-22 18:31:44,300 - mmdet - INFO - Epoch [1][170/13219]	lr: 2.500e-03, eta: 4:02:53, time: 0.348, data_time: 0.030, memory: 4208, loss_rpn_cls: 0.0917, loss_rpn_bbox: 0.0802, loss_cls: 0.7135, acc: 80.3906, loss_bbox: 0.6789, loss_mask: 0.3785, loss: 1.9428
# 2021-11-22 18:31:47,868 - mmdet - INFO - Epoch [1][180/13219]	lr: 2.500e-03, eta: 4:02:22, time: 0.357, data_time: 0.040, memory: 4208, loss_rpn_cls: 0.0744, loss_rpn_bbox: 0.0779, loss_cls: 0.7540, acc: 78.9941, loss_bbox: 0.7221, loss_mask: 0.3737, loss: 2.0022
# 2021-11-22 18:31:51,479 - mmdet - INFO - Epoch [1][190/13219]	lr: 2.500e-03, eta: 4:02:06, time: 0.362, data_time: 0.042, memory: 4208, loss_rpn_cls: 0.1175, loss_rpn_bbox: 0.1018, loss_cls: 0.7427, acc: 79.7168, loss_bbox: 0.6726, loss_mask: 0.3953, loss: 2.0298
# 2021-11-22 18:31:54,998 - mmdet - INFO - Epoch [1][200/13219]	lr: 2.500e-03, eta: 4:01:29, time: 0.351, data_time: 0.039, memory: 4208, loss_rpn_cls: 0.0951, loss_rpn_bbox: 0.0990, loss_cls: 0.6946, acc: 81.1230, loss_bbox: 0.6230, loss_mask: 0.3816, loss: 1.8934
# 2021-11-22 18:31:58,399 - mmdet - INFO - Epoch [1][210/13219]	lr: 2.500e-03, eta: 4:00:34, time: 0.340, data_time: 0.034, memory: 4208, loss_rpn_cls: 0.0948, loss_rpn_bbox: 0.0984, loss_cls: 0.7274, acc: 78.7793, loss_bbox: 0.6991, loss_mask: 0.3863, loss: 2.0059
# 2021-11-22 18:32:01,976 - mmdet - INFO - Epoch [1][220/13219]	lr: 2.500e-03, eta: 4:00:16, time: 0.358, data_time: 0.044, memory: 4208, loss_rpn_cls: 0.1013, loss_rpn_bbox: 0.0935, loss_cls: 0.7256, acc: 79.5312, loss_bbox: 0.6591, loss_mask: 0.3815, loss: 1.9611
# 2021-11-22 18:32:05,449 - mmdet - INFO - Epoch [1][230/13219]	lr: 2.500e-03, eta: 3:59:41, time: 0.347, data_time: 0.039, memory: 4208, loss_rpn_cls: 0.1127, loss_rpn_bbox: 0.1096, loss_cls: 0.7136, acc: 79.5801, loss_bbox: 0.6643, loss_mask: 0.3777, loss: 1.9779
# 2021-11-22 18:32:08,822 - mmdet - INFO - Epoch [1][240/13219]	lr: 2.500e-03, eta: 3:58:52, time: 0.337, data_time: 0.030, memory: 4208, loss_rpn_cls: 0.0844, loss_rpn_bbox: 0.1038, loss_cls: 0.6465, acc: 81.4160, loss_bbox: 0.5945, loss_mask: 0.3670, loss: 1.7962
# 2021-11-22 18:32:12,394 - mmdet - INFO - Epoch [1][250/13219]	lr: 2.500e-03, eta: 3:58:38, time: 0.358, data_time: 0.043, memory: 4208, loss_rpn_cls: 0.0936, loss_rpn_bbox: 0.0806, loss_cls: 0.6759, acc: 80.5371, loss_bbox: 0.6233, loss_mask: 0.3440, loss: 1.8174
# 2021-11-22 18:32:16,294 - mmdet - INFO - Epoch [1][260/13219]	lr: 2.500e-03, eta: 3:59:14, time: 0.389, data_time: 0.053, memory: 4208, loss_rpn_cls: 0.1141, loss_rpn_bbox: 0.1304, loss_cls: 0.7503, acc: 78.1543, loss_bbox: 0.7063, loss_mask: 0.3752, loss: 2.0763
# 2021-11-22 18:32:19,963 - mmdet - INFO - Epoch [1][270/13219]	lr: 2.500e-03, eta: 3:59:15, time: 0.367, data_time: 0.053, memory: 4208, loss_rpn_cls: 0.1555, loss_rpn_bbox: 0.1163, loss_cls: 0.7190, acc: 79.9414, loss_bbox: 0.6456, loss_mask: 0.3972, loss: 2.0335
# 2021-11-22 18:32:23,497 - mmdet - INFO - Epoch [1][280/13219]	lr: 2.500e-03, eta: 3:58:55, time: 0.353, data_time: 0.035, memory: 4208, loss_rpn_cls: 0.1353, loss_rpn_bbox: 0.0993, loss_cls: 0.7251, acc: 79.8438, loss_bbox: 0.6521, loss_mask: 0.3706, loss: 1.9825
# 2021-11-22 18:32:27,231 - mmdet - INFO - Epoch [1][290/13219]	lr: 2.500e-03, eta: 3:59:04, time: 0.373, data_time: 0.049, memory: 4208, loss_rpn_cls: 0.1256, loss_rpn_bbox: 0.1044, loss_cls: 0.7448, acc: 78.8672, loss_bbox: 0.6597, loss_mask: 0.3867, loss: 2.0212
# 2021-11-22 18:32:30,942 - mmdet - INFO - Epoch [1][300/13219]	lr: 2.500e-03, eta: 3:59:10, time: 0.372, data_time: 0.050, memory: 4208, loss_rpn_cls: 0.1361, loss_rpn_bbox: 0.1231, loss_cls: 0.7155, acc: 80.1855, loss_bbox: 0.6275, loss_mask: 0.3796, loss: 1.9817
# 2021-11-22 18:32:34,424 - mmdet - INFO - Epoch [1][310/13219]	lr: 2.500e-03, eta: 3:58:45, time: 0.348, data_time: 0.036, memory: 4208, loss_rpn_cls: 0.0812, loss_rpn_bbox: 0.0964, loss_cls: 0.6892, acc: 80.1562, loss_bbox: 0.6515, loss_mask: 0.3656, loss: 1.8840
# 2021-11-22 18:32:37,926 - mmdet - INFO - Epoch [1][320/13219]	lr: 2.500e-03, eta: 3:58:24, time: 0.350, data_time: 0.044, memory: 4208, loss_rpn_cls: 0.0937, loss_rpn_bbox: 0.0993, loss_cls: 0.6205, acc: 80.7129, loss_bbox: 0.6150, loss_mask: 0.3521, loss: 1.7805
# 2021-11-22 18:32:41,317 - mmdet - INFO - Epoch [1][330/13219]	lr: 2.500e-03, eta: 3:57:51, time: 0.339, data_time: 0.031, memory: 4208, loss_rpn_cls: 0.0695, loss_rpn_bbox: 0.0803, loss_cls: 0.6556, acc: 80.8691, loss_bbox: 0.5999, loss_mask: 0.3501, loss: 1.7554
# 2021-11-22 18:32:44,754 - mmdet - INFO - Epoch [1][340/13219]	lr: 2.500e-03, eta: 3:57:26, time: 0.344, data_time: 0.036, memory: 4208, loss_rpn_cls: 0.0643, loss_rpn_bbox: 0.0697, loss_cls: 0.6069, acc: 82.3535, loss_bbox: 0.5321, loss_mask: 0.3614, loss: 1.6344
# 2021-11-22 18:32:48,467 - mmdet - INFO - Epoch [1][350/13219]	lr: 2.500e-03, eta: 3:57:32, time: 0.371, data_time: 0.050, memory: 4208, loss_rpn_cls: 0.0875, loss_rpn_bbox: 0.1091, loss_cls: 0.6797, acc: 79.4434, loss_bbox: 0.6417, loss_mask: 0.3555, loss: 1.8735
# 2021-11-22 18:32:51,998 - mmdet - INFO - Epoch [1][360/13219]	lr: 2.500e-03, eta: 3:57:18, time: 0.353, data_time: 0.032, memory: 4208, loss_rpn_cls: 0.1110, loss_rpn_bbox: 0.0926, loss_cls: 0.7026, acc: 79.6484, loss_bbox: 0.6414, loss_mask: 0.3480, loss: 1.8957
# 2021-11-22 18:32:55,445 - mmdet - INFO - Epoch [1][370/13219]	lr: 2.500e-03, eta: 3:56:56, time: 0.345, data_time: 0.038, memory: 4208, loss_rpn_cls: 0.1133, loss_rpn_bbox: 0.0996, loss_cls: 0.6553, acc: 81.4941, loss_bbox: 0.6077, loss_mask: 0.3834, loss: 1.8594
# 2021-11-22 18:32:58,985 - mmdet - INFO - Epoch [1][380/13219]	lr: 2.500e-03, eta: 3:56:44, time: 0.354, data_time: 0.034, memory: 4208, loss_rpn_cls: 0.0941, loss_rpn_bbox: 0.0859, loss_cls: 0.6574, acc: 80.7812, loss_bbox: 0.6158, loss_mask: 0.3647, loss: 1.8178
# 2021-11-22 18:33:02,431 - mmdet - INFO - Epoch [1][390/13219]	lr: 2.500e-03, eta: 3:56:23, time: 0.345, data_time: 0.030, memory: 4208, loss_rpn_cls: 0.0938, loss_rpn_bbox: 0.0919, loss_cls: 0.6604, acc: 80.0000, loss_bbox: 0.6134, loss_mask: 0.3447, loss: 1.8042
# 2021-11-22 18:33:05,999 - mmdet - INFO - Epoch [1][400/13219]	lr: 2.500e-03, eta: 3:56:15, time: 0.356, data_time: 0.033, memory: 4208, loss_rpn_cls: 0.0876, loss_rpn_bbox: 0.1020, loss_cls: 0.6834, acc: 79.2188, loss_bbox: 0.6809, loss_mask: 0.3637, loss: 1.9176
# 2021-11-22 18:33:09,543 - mmdet - INFO - Epoch [1][410/13219]	lr: 2.500e-03, eta: 3:56:05, time: 0.355, data_time: 0.032, memory: 4208, loss_rpn_cls: 0.0887, loss_rpn_bbox: 0.0840, loss_cls: 0.6865, acc: 80.2832, loss_bbox: 0.6133, loss_mask: 0.3797, loss: 1.8522
# libpng warning: Ignoring iCCP chunk with declared size = 4294967295 and actual length = 33248
# 2021-11-22 18:33:13,199 - mmdet - INFO - Epoch [1][420/13219]	lr: 2.500e-03, eta: 3:56:06, time: 0.366, data_time: 0.044, memory: 4208, loss_rpn_cls: 0.0857, loss_rpn_bbox: 0.0853, loss_cls: 0.6855, acc: 79.1797, loss_bbox: 0.6245, loss_mask: 0.3691, loss: 1.8501
# 2021-11-22 18:33:16,813 - mmdet - INFO - Epoch [1][430/13219]	lr: 2.500e-03, eta: 3:56:03, time: 0.362, data_time: 0.038, memory: 4208, loss_rpn_cls: 0.0904, loss_rpn_bbox: 0.0920, loss_cls: 0.6274, acc: 81.1035, loss_bbox: 0.5984, loss_mask: 0.3654, loss: 1.7735
# 2021-11-22 18:33:20,296 - mmdet - INFO - Epoch [1][440/13219]	lr: 2.500e-03, eta: 3:55:48, time: 0.348, data_time: 0.039, memory: 4208, loss_rpn_cls: 0.0998, loss_rpn_bbox: 0.0958, loss_cls: 0.6077, acc: 81.7480, loss_bbox: 0.5749, loss_mask: 0.3496, loss: 1.7279
# 2021-11-22 18:33:23,636 - mmdet - INFO - Epoch [1][450/13219]	lr: 2.500e-03, eta: 3:55:21, time: 0.334, data_time: 0.032, memory: 4208, loss_rpn_cls: 0.0791, loss_rpn_bbox: 0.0871, loss_cls: 0.5972, acc: 81.7090, loss_bbox: 0.5719, loss_mask: 0.3822, loss: 1.7176
# 2021-11-22 18:33:27,198 - mmdet - INFO - Epoch [1][460/13219]	lr: 2.500e-03, eta: 3:55:14, time: 0.356, data_time: 0.036, memory: 4208, loss_rpn_cls: 0.0779, loss_rpn_bbox: 0.0878, loss_cls: 0.5878, acc: 81.4844, loss_bbox: 0.5722, loss_mask: 0.3407, loss: 1.6664
# 2021-11-22 18:33:30,724 - mmdet - INFO - Epoch [1][470/13219]	lr: 2.500e-03, eta: 3:55:04, time: 0.353, data_time: 0.036, memory: 4208, loss_rpn_cls: 0.0681, loss_rpn_bbox: 0.0748, loss_cls: 0.6220, acc: 80.3906, loss_bbox: 0.5943, loss_mask: 0.3616, loss: 1.7207
# 2021-11-22 18:33:34,550 - mmdet - INFO - Epoch [1][480/13219]	lr: 2.500e-03, eta: 3:55:19, time: 0.383, data_time: 0.054, memory: 4208, loss_rpn_cls: 0.1063, loss_rpn_bbox: 0.1113, loss_cls: 0.6336, acc: 79.7559, loss_bbox: 0.6529, loss_mask: 0.3621, loss: 1.8663
# 2021-11-22 18:33:38,257 - mmdet - INFO - Epoch [1][490/13219]	lr: 2.500e-03, eta: 3:55:23, time: 0.371, data_time: 0.049, memory: 4208, loss_rpn_cls: 0.1135, loss_rpn_bbox: 0.1065, loss_cls: 0.6677, acc: 79.1797, loss_bbox: 0.6312, loss_mask: 0.3555, loss: 1.8744
# 2021-11-22 18:33:41,595 - mmdet - INFO - Epoch [1][500/13219]	lr: 2.500e-03, eta: 3:54:59, time: 0.334, data_time: 0.030, memory: 4208, loss_rpn_cls: 0.0690, loss_rpn_bbox: 0.0724, loss_cls: 0.5303, acc: 83.7500, loss_bbox: 0.5320, loss_mask: 0.3378, loss: 1.5415
# 2021-11-22 18:33:44,912 - mmdet - INFO - Epoch [1][510/13219]	lr: 2.500e-03, eta: 3:54:33, time: 0.332, data_time: 0.028, memory: 4208, loss_rpn_cls: 0.0836, loss_rpn_bbox: 0.0887, loss_cls: 0.6617, acc: 79.5410, loss_bbox: 0.6421, loss_mask: 0.3774, loss: 1.8535
# 2021-11-22 18:33:48,487 - mmdet - INFO - Epoch [1][520/13219]	lr: 2.500e-03, eta: 3:54:28, time: 0.357, data_time: 0.038, memory: 4208, loss_rpn_cls: 0.1109, loss_rpn_bbox: 0.1132, loss_cls: 0.6454, acc: 79.7168, loss_bbox: 0.6312, loss_mask: 0.3468, loss: 1.8474
# 2021-11-22 18:33:52,038 - mmdet - INFO - Epoch [1][530/13219]	lr: 2.500e-03, eta: 3:54:21, time: 0.355, data_time: 0.051, memory: 4208, loss_rpn_cls: 0.0973, loss_rpn_bbox: 0.1044, loss_cls: 0.6348, acc: 80.4395, loss_bbox: 0.6297, loss_mask: 0.3577, loss: 1.8240
# 2021-11-22 18:33:55,549 - mmdet - INFO - Epoch [1][540/13219]	lr: 2.500e-03, eta: 3:54:12, time: 0.351, data_time: 0.038, memory: 4208, loss_rpn_cls: 0.0757, loss_rpn_bbox: 0.0763, loss_cls: 0.6663, acc: 80.5957, loss_bbox: 0.6198, loss_mask: 0.3554, loss: 1.7935
# 2021-11-22 18:33:59,187 - mmdet - INFO - Epoch [1][550/13219]	lr: 2.500e-03, eta: 3:54:12, time: 0.365, data_time: 0.041, memory: 4208, loss_rpn_cls: 0.0956, loss_rpn_bbox: 0.0940, loss_cls: 0.6268, acc: 81.0742, loss_bbox: 0.5664, loss_mask: 0.3608, loss: 1.7436
# 2021-11-22 18:34:02,751 - mmdet - INFO - Epoch [1][560/13219]	lr: 2.500e-03, eta: 3:54:06, time: 0.356, data_time: 0.042, memory: 4208, loss_rpn_cls: 0.0768, loss_rpn_bbox: 0.1004, loss_cls: 0.5808, acc: 82.2168, loss_bbox: 0.5703, loss_mask: 0.3503, loss: 1.6786
# 2021-11-22 18:34:06,673 - mmdet - INFO - Epoch [1][570/13219]	lr: 2.500e-03, eta: 3:54:25, time: 0.392, data_time: 0.064, memory: 4208, loss_rpn_cls: 0.1071, loss_rpn_bbox: 0.1351, loss_cls: 0.6829, acc: 78.0664, loss_bbox: 0.6607, loss_mask: 0.3778, loss: 1.9637
# 2021-11-22 18:34:10,170 - mmdet - INFO - Epoch [1][580/13219]	lr: 2.500e-03, eta: 3:54:14, time: 0.350, data_time: 0.034, memory: 4208, loss_rpn_cls: 0.0750, loss_rpn_bbox: 0.0851, loss_cls: 0.6586, acc: 79.6387, loss_bbox: 0.6346, loss_mask: 0.3470, loss: 1.8003
# 2021-11-22 18:34:13,816 - mmdet - INFO - Epoch [1][590/13219]	lr: 2.500e-03, eta: 3:54:14, time: 0.365, data_time: 0.042, memory: 4208, loss_rpn_cls: 0.0888, loss_rpn_bbox: 0.0944, loss_cls: 0.6064, acc: 79.9414, loss_bbox: 0.6131, loss_mask: 0.3280, loss: 1.7307
# 2021-11-22 18:34:17,367 - mmdet - INFO - Epoch [1][600/13219]	lr: 2.500e-03, eta: 3:54:07, time: 0.355, data_time: 0.034, memory: 4208, loss_rpn_cls: 0.1148, loss_rpn_bbox: 0.0933, loss_cls: 0.6228, acc: 80.7227, loss_bbox: 0.5955, loss_mask: 0.3766, loss: 1.8030
# 2021-11-22 18:34:20,850 - mmdet - INFO - Epoch [1][610/13219]	lr: 2.500e-03, eta: 3:53:56, time: 0.348, data_time: 0.039, memory: 4208, loss_rpn_cls: 0.0753, loss_rpn_bbox: 0.0839, loss_cls: 0.6022, acc: 81.4648, loss_bbox: 0.5855, loss_mask: 0.3400, loss: 1.6869
# 2021-11-22 18:34:24,351 - mmdet - INFO - Epoch [1][620/13219]	lr: 2.500e-03, eta: 3:53:47, time: 0.350, data_time: 0.045, memory: 4208, loss_rpn_cls: 0.1077, loss_rpn_bbox: 0.1151, loss_cls: 0.6451, acc: 80.1758, loss_bbox: 0.6127, loss_mask: 0.3627, loss: 1.8434
# 2021-11-22 18:34:27,739 - mmdet - INFO - Epoch [1][630/13219]	lr: 2.500e-03, eta: 3:53:31, time: 0.340, data_time: 0.030, memory: 4208, loss_rpn_cls: 0.0934, loss_rpn_bbox: 0.0694, loss_cls: 0.5694, acc: 81.6211, loss_bbox: 0.5374, loss_mask: 0.3209, loss: 1.5905
# 2021-11-22 18:34:31,153 - mmdet - INFO - Epoch [1][640/13219]	lr: 2.500e-03, eta: 3:53:16, time: 0.341, data_time: 0.027, memory: 4208, loss_rpn_cls: 0.0703, loss_rpn_bbox: 0.0697, loss_cls: 0.6006, acc: 80.1953, loss_bbox: 0.6091, loss_mask: 0.3397, loss: 1.6893
# 2021-11-22 18:34:34,827 - mmdet - INFO - Epoch [1][650/13219]	lr: 2.500e-03, eta: 3:53:18, time: 0.368, data_time: 0.049, memory: 4208, loss_rpn_cls: 0.0915, loss_rpn_bbox: 0.1092, loss_cls: 0.6370, acc: 79.9121, loss_bbox: 0.6077, loss_mask: 0.3414, loss: 1.7868
# 2021-11-22 18:34:38,314 - mmdet - INFO - Epoch [1][660/13219]	lr: 2.500e-03, eta: 3:53:08, time: 0.348, data_time: 0.043, memory: 4208, loss_rpn_cls: 0.0663, loss_rpn_bbox: 0.0902, loss_cls: 0.6229, acc: 80.5566, loss_bbox: 0.5974, loss_mask: 0.3441, loss: 1.7210
# 2021-11-22 18:34:41,972 - mmdet - INFO - Epoch [1][670/13219]	lr: 2.500e-03, eta: 3:53:09, time: 0.366, data_time: 0.047, memory: 4208, loss_rpn_cls: 0.1038, loss_rpn_bbox: 0.1107, loss_cls: 0.7143, acc: 78.4766, loss_bbox: 0.6319, loss_mask: 0.3750, loss: 1.9357
# 2021-11-22 18:34:45,424 - mmdet - INFO - Epoch [1][680/13219]	lr: 2.500e-03, eta: 3:52:58, time: 0.346, data_time: 0.036, memory: 4208, loss_rpn_cls: 0.0784, loss_rpn_bbox: 0.0966, loss_cls: 0.6282, acc: 80.6836, loss_bbox: 0.5955, loss_mask: 0.3696, loss: 1.7683
# 2021-11-22 18:34:48,867 - mmdet - INFO - Epoch [1][690/13219]	lr: 2.500e-03, eta: 3:52:46, time: 0.344, data_time: 0.036, memory: 4208, loss_rpn_cls: 0.0790, loss_rpn_bbox: 0.0928, loss_cls: 0.6855, acc: 79.0723, loss_bbox: 0.6633, loss_mask: 0.3603, loss: 1.8810
# 2021-11-22 18:34:52,360 - mmdet - INFO - Epoch [1][700/13219]	lr: 2.500e-03, eta: 3:52:37, time: 0.349, data_time: 0.029, memory: 4208, loss_rpn_cls: 0.1064, loss_rpn_bbox: 0.0934, loss_cls: 0.6288, acc: 80.8203, loss_bbox: 0.5791, loss_mask: 0.3530, loss: 1.7607
# 2021-11-22 18:34:55,972 - mmdet - INFO - Epoch [1][710/13219]	lr: 2.500e-03, eta: 3:52:35, time: 0.362, data_time: 0.042, memory: 4208, loss_rpn_cls: 0.1123, loss_rpn_bbox: 0.1023, loss_cls: 0.6545, acc: 80.3418, loss_bbox: 0.6165, loss_mask: 0.3679, loss: 1.8535
# 2021-11-22 18:34:59,552 - mmdet - INFO - Epoch [1][720/13219]	lr: 2.500e-03, eta: 3:52:31, time: 0.358, data_time: 0.034, memory: 4208, loss_rpn_cls: 0.0782, loss_rpn_bbox: 0.0869, loss_cls: 0.6271, acc: 80.8789, loss_bbox: 0.6039, loss_mask: 0.3729, loss: 1.7691
# 2021-11-22 18:35:03,094 - mmdet - INFO - Epoch [1][730/13219]	lr: 2.500e-03, eta: 3:52:25, time: 0.354, data_time: 0.031, memory: 4208, loss_rpn_cls: 0.0754, loss_rpn_bbox: 0.0728, loss_cls: 0.6714, acc: 78.9844, loss_bbox: 0.6368, loss_mask: 0.3613, loss: 1.8176
# 2021-11-22 18:35:06,887 - mmdet - INFO - Epoch [1][740/13219]	lr: 2.500e-03, eta: 3:52:33, time: 0.380, data_time: 0.056, memory: 4209, loss_rpn_cls: 0.0901, loss_rpn_bbox: 0.1132, loss_cls: 0.6624, acc: 79.4141, loss_bbox: 0.6056, loss_mask: 0.3558, loss: 1.8271
# 2021-11-22 18:35:10,242 - mmdet - INFO - Epoch [1][750/13219]	lr: 2.500e-03, eta: 3:52:18, time: 0.335, data_time: 0.033, memory: 4209, loss_rpn_cls: 0.0710, loss_rpn_bbox: 0.0688, loss_cls: 0.5819, acc: 81.3965, loss_bbox: 0.5717, loss_mask: 0.3447, loss: 1.6382
# 2021-11-22 18:35:13,811 - mmdet - INFO - Epoch [1][760/13219]	lr: 2.500e-03, eta: 3:52:13, time: 0.357, data_time: 0.039, memory: 4209, loss_rpn_cls: 0.0898, loss_rpn_bbox: 0.0982, loss_cls: 0.6339, acc: 79.7852, loss_bbox: 0.5918, loss_mask: 0.3553, loss: 1.7690
# 2021-11-22 18:35:17,300 - mmdet - INFO - Epoch [1][770/13219]	lr: 2.500e-03, eta: 3:52:05, time: 0.349, data_time: 0.038, memory: 4209, loss_rpn_cls: 0.0953, loss_rpn_bbox: 0.1025, loss_cls: 0.6084, acc: 80.3809, loss_bbox: 0.5858, loss_mask: 0.3521, loss: 1.7441
# 2021-11-22 18:35:20,766 - mmdet - INFO - Epoch [1][780/13219]	lr: 2.500e-03, eta: 3:51:56, time: 0.346, data_time: 0.031, memory: 4209, loss_rpn_cls: 0.0772, loss_rpn_bbox: 0.0864, loss_cls: 0.6115, acc: 80.7129, loss_bbox: 0.5674, loss_mask: 0.3296, loss: 1.6720
# 2021-11-22 18:35:24,222 - mmdet - INFO - Epoch [1][790/13219]	lr: 2.500e-03, eta: 3:51:46, time: 0.346, data_time: 0.032, memory: 4209, loss_rpn_cls: 0.0686, loss_rpn_bbox: 0.0835, loss_cls: 0.6518, acc: 79.4336, loss_bbox: 0.5967, loss_mask: 0.3220, loss: 1.7226
# 2021-11-22 18:35:27,790 - mmdet - INFO - Epoch [1][800/13219]	lr: 2.500e-03, eta: 3:51:42, time: 0.357, data_time: 0.041, memory: 4209, loss_rpn_cls: 0.0639, loss_rpn_bbox: 0.0862, loss_cls: 0.6058, acc: 79.8340, loss_bbox: 0.6264, loss_mask: 0.3339, loss: 1.7161
# 2021-11-22 18:35:31,146 - mmdet - INFO - Epoch [1][810/13219]	lr: 2.500e-03, eta: 3:51:28, time: 0.336, data_time: 0.034, memory: 4209, loss_rpn_cls: 0.1040, loss_rpn_bbox: 0.0777, loss_cls: 0.5846, acc: 80.4785, loss_bbox: 0.5720, loss_mask: 0.3437, loss: 1.6820
# 2021-11-22 18:35:34,628 - mmdet - INFO - Epoch [1][820/13219]	lr: 2.500e-03, eta: 3:51:20, time: 0.348, data_time: 0.033, memory: 4209, loss_rpn_cls: 0.0978, loss_rpn_bbox: 0.0848, loss_cls: 0.6191, acc: 81.4062, loss_bbox: 0.5625, loss_mask: 0.3504, loss: 1.7145
# 2021-11-22 18:35:38,010 - mmdet - INFO - Epoch [1][830/13219]	lr: 2.500e-03, eta: 3:51:07, time: 0.338, data_time: 0.030, memory: 4209, loss_rpn_cls: 0.0826, loss_rpn_bbox: 0.0741, loss_cls: 0.6621, acc: 79.8145, loss_bbox: 0.5883, loss_mask: 0.3355, loss: 1.7425
# 2021-11-22 18:35:41,676 - mmdet - INFO - Epoch [1][840/13219]	lr: 2.500e-03, eta: 3:51:08, time: 0.367, data_time: 0.049, memory: 4209, loss_rpn_cls: 0.0907, loss_rpn_bbox: 0.0997, loss_cls: 0.6159, acc: 80.4492, loss_bbox: 0.5816, loss_mask: 0.3453, loss: 1.7331
# 2021-11-22 18:35:45,170 - mmdet - INFO - Epoch [1][850/13219]	lr: 2.500e-03, eta: 3:51:01, time: 0.350, data_time: 0.034, memory: 4209, loss_rpn_cls: 0.0717, loss_rpn_bbox: 0.0787, loss_cls: 0.5918, acc: 81.2012, loss_bbox: 0.5839, loss_mask: 0.3315, loss: 1.6575
# 2021-11-22 18:35:48,785 - mmdet - INFO - Epoch [1][860/13219]	lr: 2.500e-03, eta: 3:50:59, time: 0.362, data_time: 0.040, memory: 4209, loss_rpn_cls: 0.0971, loss_rpn_bbox: 0.1063, loss_cls: 0.6508, acc: 80.1465, loss_bbox: 0.5872, loss_mask: 0.3389, loss: 1.7804
# 2021-11-22 18:35:52,374 - mmdet - INFO - Epoch [1][870/13219]	lr: 2.500e-03, eta: 3:50:56, time: 0.358, data_time: 0.033, memory: 4209, loss_rpn_cls: 0.0608, loss_rpn_bbox: 0.0733, loss_cls: 0.6320, acc: 79.9805, loss_bbox: 0.5986, loss_mask: 0.3475, loss: 1.7122
# 2021-11-22 18:35:56,029 - mmdet - INFO - Epoch [1][880/13219]	lr: 2.500e-03, eta: 3:50:56, time: 0.366, data_time: 0.038, memory: 4209, loss_rpn_cls: 0.0780, loss_rpn_bbox: 0.0809, loss_cls: 0.6373, acc: 80.0488, loss_bbox: 0.5922, loss_mask: 0.3377, loss: 1.7260
# 2021-11-22 18:35:59,469 - mmdet - INFO - Epoch [1][890/13219]	lr: 2.500e-03, eta: 3:50:47, time: 0.344, data_time: 0.036, memory: 4209, loss_rpn_cls: 0.0738, loss_rpn_bbox: 0.0805, loss_cls: 0.6271, acc: 80.8691, loss_bbox: 0.5952, loss_mask: 0.3473, loss: 1.7238
# 2021-11-22 18:36:02,979 - mmdet - INFO - Epoch [1][900/13219]	lr: 2.500e-03, eta: 3:50:41, time: 0.351, data_time: 0.038, memory: 4209, loss_rpn_cls: 0.1036, loss_rpn_bbox: 0.1061, loss_cls: 0.6352, acc: 80.9863, loss_bbox: 0.5627, loss_mask: 0.3659, loss: 1.7735
# 2021-11-22 18:36:06,555 - mmdet - INFO - Epoch [1][910/13219]	lr: 2.500e-03, eta: 3:50:37, time: 0.357, data_time: 0.035, memory: 4209, loss_rpn_cls: 0.0859, loss_rpn_bbox: 0.0956, loss_cls: 0.6309, acc: 80.3418, loss_bbox: 0.5907, loss_mask: 0.3382, loss: 1.7413
# 2021-11-22 18:36:10,044 - mmdet - INFO - Epoch [1][920/13219]	lr: 2.500e-03, eta: 3:50:30, time: 0.349, data_time: 0.029, memory: 4209, loss_rpn_cls: 0.0545, loss_rpn_bbox: 0.0662, loss_cls: 0.5738, acc: 81.2207, loss_bbox: 0.5687, loss_mask: 0.3192, loss: 1.5825
# 2021-11-22 18:36:13,603 - mmdet - INFO - Epoch [1][930/13219]	lr: 2.500e-03, eta: 3:50:26, time: 0.355, data_time: 0.037, memory: 4209, loss_rpn_cls: 0.0743, loss_rpn_bbox: 0.0817, loss_cls: 0.6568, acc: 79.7656, loss_bbox: 0.6301, loss_mask: 0.3767, loss: 1.8197
# 2021-11-22 18:36:17,036 - mmdet - INFO - Epoch [1][940/13219]	lr: 2.500e-03, eta: 3:50:17, time: 0.344, data_time: 0.034, memory: 4209, loss_rpn_cls: 0.0953, loss_rpn_bbox: 0.0871, loss_cls: 0.6201, acc: 80.6738, loss_bbox: 0.6112, loss_mask: 0.3636, loss: 1.7774
# 2021-11-22 18:36:20,383 - mmdet - INFO - Epoch [1][950/13219]	lr: 2.500e-03, eta: 3:50:05, time: 0.334, data_time: 0.030, memory: 4209, loss_rpn_cls: 0.0640, loss_rpn_bbox: 0.0739, loss_cls: 0.6119, acc: 80.2930, loss_bbox: 0.5743, loss_mask: 0.3513, loss: 1.6753
# 2021-11-22 18:36:24,122 - mmdet - INFO - Epoch [1][960/13219]	lr: 2.500e-03, eta: 3:50:08, time: 0.374, data_time: 0.048, memory: 4209, loss_rpn_cls: 0.0699, loss_rpn_bbox: 0.0929, loss_cls: 0.6030, acc: 80.6250, loss_bbox: 0.5677, loss_mask: 0.3293, loss: 1.6628
# 2021-11-22 18:36:27,549 - mmdet - INFO - Epoch [1][970/13219]	lr: 2.500e-03, eta: 3:49:59, time: 0.343, data_time: 0.027, memory: 4209, loss_rpn_cls: 0.0596, loss_rpn_bbox: 0.0715, loss_cls: 0.6373, acc: 79.8438, loss_bbox: 0.5993, loss_mask: 0.3524, loss: 1.7200
# 2021-11-22 18:36:31,144 - mmdet - INFO - Epoch [1][980/13219]	lr: 2.500e-03, eta: 3:49:56, time: 0.360, data_time: 0.044, memory: 4209, loss_rpn_cls: 0.0724, loss_rpn_bbox: 0.0875, loss_cls: 0.6380, acc: 80.3516, loss_bbox: 0.5953, loss_mask: 0.3334, loss: 1.7266
# 2021-11-22 18:36:34,693 - mmdet - INFO - Epoch [1][990/13219]	lr: 2.500e-03, eta: 3:49:52, time: 0.355, data_time: 0.040, memory: 4209, loss_rpn_cls: 0.0837, loss_rpn_bbox: 0.1017, loss_cls: 0.6324, acc: 79.6289, loss_bbox: 0.5975, loss_mask: 0.3450, loss: 1.7604
# 2021-11-22 18:36:38,086 - mmdet - INFO - Epoch [1][1000/13219]	lr: 2.500e-03, eta: 3:49:42, time: 0.339, data_time: 0.027, memory: 4209, loss_rpn_cls: 0.0726, loss_rpn_bbox: 0.0727, loss_cls: 0.6047, acc: 80.8105, loss_bbox: 0.5614, loss_mask: 0.3401, loss: 1.6515
# 2021-11-22 18:36:41,705 - mmdet - INFO - Epoch [1][1010/13219]	lr: 2.500e-03, eta: 3:49:40, time: 0.362, data_time: 0.042, memory: 4209, loss_rpn_cls: 0.0859, loss_rpn_bbox: 0.0955, loss_cls: 0.6401, acc: 79.9805, loss_bbox: 0.5830, loss_mask: 0.3505, loss: 1.7550
# 2021-11-22 18:36:45,291 - mmdet - INFO - Epoch [1][1020/13219]	lr: 2.500e-03, eta: 3:49:37, time: 0.358, data_time: 0.039, memory: 4209, loss_rpn_cls: 0.0802, loss_rpn_bbox: 0.0901, loss_cls: 0.6541, acc: 79.6094, loss_bbox: 0.6116, loss_mask: 0.3488, loss: 1.7848
# 2021-11-22 18:36:48,788 - mmdet - INFO - Epoch [1][1030/13219]	lr: 2.500e-03, eta: 3:49:31, time: 0.350, data_time: 0.030, memory: 4209, loss_rpn_cls: 0.0723, loss_rpn_bbox: 0.0759, loss_cls: 0.5058, acc: 82.9785, loss_bbox: 0.5227, loss_mask: 0.3196, loss: 1.4963
# 2021-11-22 18:36:52,241 - mmdet - INFO - Epoch [1][1040/13219]	lr: 2.500e-03, eta: 3:49:24, time: 0.346, data_time: 0.030, memory: 4209, loss_rpn_cls: 0.0547, loss_rpn_bbox: 0.0760, loss_cls: 0.6074, acc: 79.2969, loss_bbox: 0.6260, loss_mask: 0.3276, loss: 1.6918
# 2021-11-22 18:36:55,706 - mmdet - INFO - Epoch [1][1050/13219]	lr: 2.500e-03, eta: 3:49:16, time: 0.346, data_time: 0.034, memory: 4209, loss_rpn_cls: 0.0750, loss_rpn_bbox: 0.0792, loss_cls: 0.6904, acc: 79.4141, loss_bbox: 0.6032, loss_mask: 0.3402, loss: 1.7881
# 2021-11-22 18:36:59,170 - mmdet - INFO - Epoch [1][1060/13219]	lr: 2.500e-03, eta: 3:49:09, time: 0.346, data_time: 0.031, memory: 4209, loss_rpn_cls: 0.0769, loss_rpn_bbox: 0.0814, loss_cls: 0.6244, acc: 79.6387, loss_bbox: 0.5907, loss_mask: 0.3423, loss: 1.7158
# 2021-11-22 18:37:02,765 - mmdet - INFO - Epoch [1][1070/13219]	lr: 2.500e-03, eta: 3:49:07, time: 0.359, data_time: 0.039, memory: 4209, loss_rpn_cls: 0.0869, loss_rpn_bbox: 0.0824, loss_cls: 0.6196, acc: 79.9414, loss_bbox: 0.5897, loss_mask: 0.3288, loss: 1.7074
# 2021-11-22 18:37:06,182 - mmdet - INFO - Epoch [1][1080/13219]	lr: 2.500e-03, eta: 3:48:58, time: 0.342, data_time: 0.031, memory: 4209, loss_rpn_cls: 0.0784, loss_rpn_bbox: 0.0920, loss_cls: 0.6623, acc: 79.1113, loss_bbox: 0.6294, loss_mask: 0.3587, loss: 1.8209
# 2021-11-22 18:37:09,625 - mmdet - INFO - Epoch [1][1090/13219]	lr: 2.500e-03, eta: 3:48:50, time: 0.345, data_time: 0.031, memory: 4209, loss_rpn_cls: 0.0718, loss_rpn_bbox: 0.0761, loss_cls: 0.5816, acc: 81.3379, loss_bbox: 0.5761, loss_mask: 0.3432, loss: 1.6489
# 2021-11-22 18:37:13,077 - mmdet - INFO - Epoch [1][1100/13219]	lr: 2.500e-03, eta: 3:48:43, time: 0.345, data_time: 0.032, memory: 4209, loss_rpn_cls: 0.0654, loss_rpn_bbox: 0.0744, loss_cls: 0.5741, acc: 81.9141, loss_bbox: 0.5369, loss_mask: 0.3421, loss: 1.5928
# 2021-11-22 18:37:16,719 - mmdet - INFO - Epoch [1][1110/13219]	lr: 2.500e-03, eta: 3:48:42, time: 0.364, data_time: 0.040, memory: 4209, loss_rpn_cls: 0.0827, loss_rpn_bbox: 0.0897, loss_cls: 0.6354, acc: 80.1074, loss_bbox: 0.5917, loss_mask: 0.3478, loss: 1.7473
# 2021-11-22 18:37:20,181 - mmdet - INFO - Epoch [1][1120/13219]	lr: 2.500e-03, eta: 3:48:35, time: 0.346, data_time: 0.043, memory: 4209, loss_rpn_cls: 0.0805, loss_rpn_bbox: 0.0963, loss_cls: 0.6449, acc: 79.8730, loss_bbox: 0.5770, loss_mask: 0.3314, loss: 1.7302
# 2021-11-22 18:37:23,635 - mmdet - INFO - Epoch [1][1130/13219]	lr: 2.500e-03, eta: 3:48:28, time: 0.345, data_time: 0.029, memory: 4209, loss_rpn_cls: 0.0605, loss_rpn_bbox: 0.0768, loss_cls: 0.5994, acc: 82.0703, loss_bbox: 0.5524, loss_mask: 0.3488, loss: 1.6379
# 2021-11-22 18:37:27,154 - mmdet - INFO - Epoch [1][1140/13219]	lr: 2.500e-03, eta: 3:48:23, time: 0.352, data_time: 0.033, memory: 4209, loss_rpn_cls: 0.0587, loss_rpn_bbox: 0.0727, loss_cls: 0.6084, acc: 80.7129, loss_bbox: 0.5908, loss_mask: 0.3317, loss: 1.6624
# 2021-11-22 18:37:30,654 - mmdet - INFO - Epoch [1][1150/13219]	lr: 2.500e-03, eta: 3:48:18, time: 0.350, data_time: 0.030, memory: 4209, loss_rpn_cls: 0.0739, loss_rpn_bbox: 0.0778, loss_cls: 0.6216, acc: 81.1230, loss_bbox: 0.6018, loss_mask: 0.3610, loss: 1.7361
# 2021-11-22 18:37:34,432 - mmdet - INFO - Epoch [1][1160/13219]	lr: 2.500e-03, eta: 3:48:21, time: 0.377, data_time: 0.053, memory: 4209, loss_rpn_cls: 0.0882, loss_rpn_bbox: 0.0810, loss_cls: 0.5655, acc: 82.3340, loss_bbox: 0.5057, loss_mask: 0.3230, loss: 1.5635
# 2021-11-22 18:37:38,282 - mmdet - INFO - Epoch [1][1170/13219]	lr: 2.500e-03, eta: 3:48:27, time: 0.385, data_time: 0.058, memory: 4209, loss_rpn_cls: 0.1225, loss_rpn_bbox: 0.1016, loss_cls: 0.6617, acc: 80.5957, loss_bbox: 0.5880, loss_mask: 0.3756, loss: 1.8494
# 2021-11-22 18:37:41,764 - mmdet - INFO - Epoch [1][1180/13219]	lr: 2.500e-03, eta: 3:48:21, time: 0.348, data_time: 0.037, memory: 4209, loss_rpn_cls: 0.1115, loss_rpn_bbox: 0.1086, loss_cls: 0.6628, acc: 80.5859, loss_bbox: 0.5901, loss_mask: 0.3548, loss: 1.8278
# 2021-11-22 18:37:45,291 - mmdet - INFO - Epoch [1][1190/13219]	lr: 2.500e-03, eta: 3:48:17, time: 0.353, data_time: 0.030, memory: 4209, loss_rpn_cls: 0.0587, loss_rpn_bbox: 0.0844, loss_cls: 0.5995, acc: 80.2441, loss_bbox: 0.5923, loss_mask: 0.3309, loss: 1.6659
# 2021-11-22 18:37:48,793 - mmdet - INFO - Epoch [1][1200/13219]	lr: 2.500e-03, eta: 3:48:11, time: 0.351, data_time: 0.036, memory: 4209, loss_rpn_cls: 0.0991, loss_rpn_bbox: 0.0800, loss_cls: 0.5748, acc: 81.6211, loss_bbox: 0.5214, loss_mask: 0.3321, loss: 1.6075
# 2021-11-22 18:37:52,363 - mmdet - INFO - Epoch [1][1210/13219]	lr: 2.500e-03, eta: 3:48:08, time: 0.357, data_time: 0.035, memory: 4209, loss_rpn_cls: 0.0842, loss_rpn_bbox: 0.0950, loss_cls: 0.5997, acc: 80.2734, loss_bbox: 0.5989, loss_mask: 0.3634, loss: 1.7411
# 2021-11-22 18:37:56,025 - mmdet - INFO - Epoch [1][1220/13219]	lr: 2.500e-03, eta: 3:48:08, time: 0.366, data_time: 0.046, memory: 4209, loss_rpn_cls: 0.0936, loss_rpn_bbox: 0.0967, loss_cls: 0.5470, acc: 81.1328, loss_bbox: 0.5449, loss_mask: 0.3271, loss: 1.6094
# 2021-11-22 18:37:59,712 - mmdet - INFO - Epoch [1][1230/13219]	lr: 2.500e-03, eta: 3:48:08, time: 0.369, data_time: 0.054, memory: 4209, loss_rpn_cls: 0.0767, loss_rpn_bbox: 0.0868, loss_cls: 0.5925, acc: 80.4395, loss_bbox: 0.5484, loss_mask: 0.3254, loss: 1.6297
# 2021-11-22 18:38:03,367 - mmdet - INFO - Epoch [1][1240/13219]	lr: 2.500e-03, eta: 3:48:07, time: 0.365, data_time: 0.042, memory: 4209, loss_rpn_cls: 0.0657, loss_rpn_bbox: 0.0879, loss_cls: 0.6159, acc: 80.4102, loss_bbox: 0.5770, loss_mask: 0.3268, loss: 1.6732
# 2021-11-22 18:38:06,739 - mmdet - INFO - Epoch [1][1250/13219]	lr: 2.500e-03, eta: 3:47:58, time: 0.337, data_time: 0.027, memory: 4209, loss_rpn_cls: 0.0929, loss_rpn_bbox: 0.0714, loss_cls: 0.5608, acc: 81.7969, loss_bbox: 0.5668, loss_mask: 0.3515, loss: 1.6434
# 2021-11-22 18:38:10,134 - mmdet - INFO - Epoch [1][1260/13219]	lr: 2.500e-03, eta: 3:47:49, time: 0.340, data_time: 0.035, memory: 4209, loss_rpn_cls: 0.0621, loss_rpn_bbox: 0.0684, loss_cls: 0.5670, acc: 82.4512, loss_bbox: 0.5241, loss_mask: 0.3317, loss: 1.5533
# 2021-11-22 18:38:13,589 - mmdet - INFO - Epoch [1][1270/13219]	lr: 2.500e-03, eta: 3:47:42, time: 0.345, data_time: 0.038, memory: 4209, loss_rpn_cls: 0.0872, loss_rpn_bbox: 0.0874, loss_cls: 0.5590, acc: 82.8418, loss_bbox: 0.5374, loss_mask: 0.3314, loss: 1.6024
# 2021-11-22 18:38:17,070 - mmdet - INFO - Epoch [1][1280/13219]	lr: 2.500e-03, eta: 3:47:37, time: 0.348, data_time: 0.037, memory: 4209, loss_rpn_cls: 0.0740, loss_rpn_bbox: 0.0990, loss_cls: 0.5302, acc: 81.7480, loss_bbox: 0.5717, loss_mask: 0.3396, loss: 1.6146
# 2021-11-22 18:38:20,453 - mmdet - INFO - Epoch [1][1290/13219]	lr: 2.500e-03, eta: 3:47:28, time: 0.338, data_time: 0.040, memory: 4209, loss_rpn_cls: 0.0789, loss_rpn_bbox: 0.0973, loss_cls: 0.5992, acc: 81.5137, loss_bbox: 0.5550, loss_mask: 0.3411, loss: 1.6716
# 2021-11-22 18:38:23,955 - mmdet - INFO - Epoch [1][1300/13219]	lr: 2.500e-03, eta: 3:47:23, time: 0.350, data_time: 0.038, memory: 4209, loss_rpn_cls: 0.1001, loss_rpn_bbox: 0.1018, loss_cls: 0.5661, acc: 81.0059, loss_bbox: 0.5813, loss_mask: 0.3295, loss: 1.6789
# 2021-11-22 18:38:27,647 - mmdet - INFO - Epoch [1][1310/13219]	lr: 2.500e-03, eta: 3:47:23, time: 0.369, data_time: 0.045, memory: 4209, loss_rpn_cls: 0.0864, loss_rpn_bbox: 0.0980, loss_cls: 0.5569, acc: 80.8105, loss_bbox: 0.5582, loss_mask: 0.3223, loss: 1.6218
# 2021-11-22 18:38:31,303 - mmdet - INFO - Epoch [1][1320/13219]	lr: 2.500e-03, eta: 3:47:22, time: 0.366, data_time: 0.050, memory: 4209, loss_rpn_cls: 0.0980, loss_rpn_bbox: 0.0950, loss_cls: 0.5906, acc: 80.5664, loss_bbox: 0.5776, loss_mask: 0.3527, loss: 1.7139
# 2021-11-22 18:38:34,891 - mmdet - INFO - Epoch [1][1330/13219]	lr: 2.500e-03, eta: 3:47:19, time: 0.358, data_time: 0.034, memory: 4209, loss_rpn_cls: 0.0959, loss_rpn_bbox: 0.1028, loss_cls: 0.5731, acc: 80.3613, loss_bbox: 0.5560, loss_mask: 0.2995, loss: 1.6274
# 2021-11-22 18:38:38,323 - mmdet - INFO - Epoch [1][1340/13219]	lr: 2.500e-03, eta: 3:47:12, time: 0.344, data_time: 0.037, memory: 4209, loss_rpn_cls: 0.0564, loss_rpn_bbox: 0.0898, loss_cls: 0.5442, acc: 81.5039, loss_bbox: 0.5588, loss_mask: 0.3274, loss: 1.5766
# 2021-11-22 18:38:41,775 - mmdet - INFO - Epoch [1][1350/13219]	lr: 2.500e-03, eta: 3:47:06, time: 0.345, data_time: 0.036, memory: 4209, loss_rpn_cls: 0.0682, loss_rpn_bbox: 0.0817, loss_cls: 0.5626, acc: 81.3770, loss_bbox: 0.5648, loss_mask: 0.3457, loss: 1.6229
# 2021-11-22 18:38:45,314 - mmdet - INFO - Epoch [1][1360/13219]	lr: 2.500e-03, eta: 3:47:02, time: 0.354, data_time: 0.044, memory: 4209, loss_rpn_cls: 0.0670, loss_rpn_bbox: 0.0878, loss_cls: 0.6423, acc: 80.8691, loss_bbox: 0.6207, loss_mask: 0.3481, loss: 1.7659
# 2021-11-22 18:38:48,797 - mmdet - INFO - Epoch [1][1370/13219]	lr: 2.500e-03, eta: 3:46:56, time: 0.348, data_time: 0.040, memory: 4209, loss_rpn_cls: 0.1092, loss_rpn_bbox: 0.0997, loss_cls: 0.6273, acc: 79.7070, loss_bbox: 0.6197, loss_mask: 0.3582, loss: 1.8140
# 2021-11-22 18:38:52,190 - mmdet - INFO - Epoch [1][1380/13219]	lr: 2.500e-03, eta: 3:46:48, time: 0.339, data_time: 0.033, memory: 4209, loss_rpn_cls: 0.0844, loss_rpn_bbox: 0.0877, loss_cls: 0.5674, acc: 81.3770, loss_bbox: 0.5166, loss_mask: 0.3444, loss: 1.6005
# 2021-11-22 18:38:55,773 - mmdet - INFO - Epoch [1][1390/13219]	lr: 2.500e-03, eta: 3:46:45, time: 0.358, data_time: 0.044, memory: 4209, loss_rpn_cls: 0.1012, loss_rpn_bbox: 0.1068, loss_cls: 0.6159, acc: 80.0684, loss_bbox: 0.5847, loss_mask: 0.3510, loss: 1.7596
# 2021-11-22 18:38:59,285 - mmdet - INFO - Epoch [1][1400/13219]	lr: 2.500e-03, eta: 3:46:40, time: 0.351, data_time: 0.041, memory: 4209, loss_rpn_cls: 0.1017, loss_rpn_bbox: 0.1046, loss_cls: 0.6149, acc: 79.7168, loss_bbox: 0.5706, loss_mask: 0.3362, loss: 1.7281
# 2021-11-22 18:39:02,868 - mmdet - INFO - Epoch [1][1410/13219]	lr: 2.500e-03, eta: 3:46:38, time: 0.358, data_time: 0.044, memory: 4209, loss_rpn_cls: 0.0874, loss_rpn_bbox: 0.1048, loss_cls: 0.6478, acc: 79.6973, loss_bbox: 0.5744, loss_mask: 0.3398, loss: 1.7542
# 2021-11-22 18:39:06,633 - mmdet - INFO - Epoch [1][1420/13219]	lr: 2.500e-03, eta: 3:46:40, time: 0.377, data_time: 0.054, memory: 4209, loss_rpn_cls: 0.0998, loss_rpn_bbox: 0.1033, loss_cls: 0.5653, acc: 82.5781, loss_bbox: 0.5259, loss_mask: 0.3361, loss: 1.6305
# 2021-11-22 18:39:10,108 - mmdet - INFO - Epoch [1][1430/13219]	lr: 2.500e-03, eta: 3:46:34, time: 0.347, data_time: 0.037, memory: 4209, loss_rpn_cls: 0.0850, loss_rpn_bbox: 0.0877, loss_cls: 0.5569, acc: 81.6309, loss_bbox: 0.5480, loss_mask: 0.3423, loss: 1.6199
# 2021-11-22 18:39:13,574 - mmdet - INFO - Epoch [1][1440/13219]	lr: 2.500e-03, eta: 3:46:28, time: 0.346, data_time: 0.038, memory: 4209, loss_rpn_cls: 0.0824, loss_rpn_bbox: 0.0889, loss_cls: 0.6140, acc: 80.2246, loss_bbox: 0.5706, loss_mask: 0.3644, loss: 1.7203
# 2021-11-22 18:39:17,070 - mmdet - INFO - Epoch [1][1450/13219]	lr: 2.500e-03, eta: 3:46:23, time: 0.350, data_time: 0.040, memory: 4209, loss_rpn_cls: 0.0899, loss_rpn_bbox: 0.1068, loss_cls: 0.6206, acc: 79.2285, loss_bbox: 0.6230, loss_mask: 0.3497, loss: 1.7901
# 2021-11-22 18:39:20,612 - mmdet - INFO - Epoch [1][1460/13219]	lr: 2.500e-03, eta: 3:46:19, time: 0.354, data_time: 0.041, memory: 4209, loss_rpn_cls: 0.0902, loss_rpn_bbox: 0.0928, loss_cls: 0.5791, acc: 80.5371, loss_bbox: 0.6147, loss_mask: 0.3721, loss: 1.7490
# 2021-11-22 18:39:24,167 - mmdet - INFO - Epoch [1][1470/13219]	lr: 2.500e-03, eta: 3:46:15, time: 0.355, data_time: 0.042, memory: 4209, loss_rpn_cls: 0.0872, loss_rpn_bbox: 0.0859, loss_cls: 0.5596, acc: 82.3145, loss_bbox: 0.5333, loss_mask: 0.3452, loss: 1.6113
# 2021-11-22 18:39:27,647 - mmdet - INFO - Epoch [1][1480/13219]	lr: 2.500e-03, eta: 3:46:10, time: 0.349, data_time: 0.047, memory: 4209, loss_rpn_cls: 0.0694, loss_rpn_bbox: 0.0914, loss_cls: 0.6014, acc: 81.1133, loss_bbox: 0.5872, loss_mask: 0.3405, loss: 1.6900
# 2021-11-22 18:39:31,176 - mmdet - INFO - Epoch [1][1490/13219]	lr: 2.500e-03, eta: 3:46:06, time: 0.353, data_time: 0.038, memory: 4209, loss_rpn_cls: 0.0746, loss_rpn_bbox: 0.0816, loss_cls: 0.5618, acc: 81.2305, loss_bbox: 0.5421, loss_mask: 0.3147, loss: 1.5747
# 2021-11-22 18:39:34,615 - mmdet - INFO - Epoch [1][1500/13219]	lr: 2.500e-03, eta: 3:45:59, time: 0.344, data_time: 0.040, memory: 4209, loss_rpn_cls: 0.0540, loss_rpn_bbox: 0.0834, loss_cls: 0.6187, acc: 79.4336, loss_bbox: 0.5921, loss_mask: 0.3188, loss: 1.6669
# 2021-11-22 18:39:38,111 - mmdet - INFO - Epoch [1][1510/13219]	lr: 2.500e-03, eta: 3:45:54, time: 0.350, data_time: 0.035, memory: 4209, loss_rpn_cls: 0.0702, loss_rpn_bbox: 0.0967, loss_cls: 0.6115, acc: 80.1465, loss_bbox: 0.5734, loss_mask: 0.3329, loss: 1.6848
# 2021-11-22 18:39:41,385 - mmdet - INFO - Epoch [1][1520/13219]	lr: 2.500e-03, eta: 3:45:44, time: 0.328, data_time: 0.029, memory: 4209, loss_rpn_cls: 0.0852, loss_rpn_bbox: 0.0885, loss_cls: 0.5943, acc: 81.2988, loss_bbox: 0.5315, loss_mask: 0.3554, loss: 1.6549
# 2021-11-22 18:39:44,686 - mmdet - INFO - Epoch [1][1530/13219]	lr: 2.500e-03, eta: 3:45:34, time: 0.330, data_time: 0.028, memory: 4209, loss_rpn_cls: 0.0918, loss_rpn_bbox: 0.0713, loss_cls: 0.5060, acc: 82.5977, loss_bbox: 0.5180, loss_mask: 0.3230, loss: 1.5101
# 2021-11-22 18:39:48,072 - mmdet - INFO - Epoch [1][1540/13219]	lr: 2.500e-03, eta: 3:45:26, time: 0.339, data_time: 0.039, memory: 4209, loss_rpn_cls: 0.0818, loss_rpn_bbox: 0.0876, loss_cls: 0.5356, acc: 82.4902, loss_bbox: 0.5146, loss_mask: 0.3128, loss: 1.5323
# 2021-11-22 18:39:51,541 - mmdet - INFO - Epoch [1][1550/13219]	lr: 2.500e-03, eta: 3:45:21, time: 0.347, data_time: 0.041, memory: 4209, loss_rpn_cls: 0.0889, loss_rpn_bbox: 0.0965, loss_cls: 0.5681, acc: 81.2695, loss_bbox: 0.5596, loss_mask: 0.3533, loss: 1.6665
# 2021-11-22 18:39:55,096 - mmdet - INFO - Epoch [1][1560/13219]	lr: 2.500e-03, eta: 3:45:17, time: 0.355, data_time: 0.032, memory: 4209, loss_rpn_cls: 0.0751, loss_rpn_bbox: 0.0829, loss_cls: 0.6265, acc: 80.2051, loss_bbox: 0.5903, loss_mask: 0.3475, loss: 1.7224
# 2021-11-22 18:39:58,658 - mmdet - INFO - Epoch [1][1570/13219]	lr: 2.500e-03, eta: 3:45:14, time: 0.356, data_time: 0.038, memory: 4209, loss_rpn_cls: 0.0613, loss_rpn_bbox: 0.0760, loss_cls: 0.5729, acc: 81.0840, loss_bbox: 0.5524, loss_mask: 0.3179, loss: 1.5804
# 2021-11-22 18:40:02,105 - mmdet - INFO - Epoch [1][1580/13219]	lr: 2.500e-03, eta: 3:45:08, time: 0.345, data_time: 0.038, memory: 4209, loss_rpn_cls: 0.0835, loss_rpn_bbox: 0.0991, loss_cls: 0.6508, acc: 78.5547, loss_bbox: 0.5908, loss_mask: 0.3121, loss: 1.7364
# 2021-11-22 18:40:05,673 - mmdet - INFO - Epoch [1][1590/13219]	lr: 2.500e-03, eta: 3:45:05, time: 0.356, data_time: 0.040, memory: 4209, loss_rpn_cls: 0.1011, loss_rpn_bbox: 0.0869, loss_cls: 0.5995, acc: 80.9277, loss_bbox: 0.5423, loss_mask: 0.3593, loss: 1.6892
# 2021-11-22 18:40:08,999 - mmdet - INFO - Epoch [1][1600/13219]	lr: 2.500e-03, eta: 3:44:56, time: 0.333, data_time: 0.028, memory: 4209, loss_rpn_cls: 0.0667, loss_rpn_bbox: 0.0711, loss_cls: 0.5326, acc: 81.9531, loss_bbox: 0.5284, loss_mask: 0.3364, loss: 1.5351
# 2021-11-22 18:40:12,446 - mmdet - INFO - Epoch [1][1610/13219]	lr: 2.500e-03, eta: 3:44:50, time: 0.345, data_time: 0.036, memory: 4209, loss_rpn_cls: 0.0711, loss_rpn_bbox: 0.0645, loss_cls: 0.5392, acc: 83.5449, loss_bbox: 0.5006, loss_mask: 0.3183, loss: 1.4937
# 2021-11-22 18:40:15,858 - mmdet - INFO - Epoch [1][1620/13219]	lr: 2.500e-03, eta: 3:44:44, time: 0.341, data_time: 0.034, memory: 4209, loss_rpn_cls: 0.0651, loss_rpn_bbox: 0.0844, loss_cls: 0.5679, acc: 80.8984, loss_bbox: 0.5602, loss_mask: 0.3254, loss: 1.6030
# 2021-11-22 18:40:19,250 - mmdet - INFO - Epoch [1][1630/13219]	lr: 2.500e-03, eta: 3:44:37, time: 0.339, data_time: 0.031, memory: 4209, loss_rpn_cls: 0.0656, loss_rpn_bbox: 0.0764, loss_cls: 0.5616, acc: 81.7480, loss_bbox: 0.5497, loss_mask: 0.3167, loss: 1.5700
# 2021-11-22 18:40:22,671 - mmdet - INFO - Epoch [1][1640/13219]	lr: 2.500e-03, eta: 3:44:30, time: 0.342, data_time: 0.032, memory: 4209, loss_rpn_cls: 0.0705, loss_rpn_bbox: 0.0979, loss_cls: 0.5559, acc: 80.7324, loss_bbox: 0.5308, loss_mask: 0.3151, loss: 1.5702
# 2021-11-22 18:40:26,178 - mmdet - INFO - Epoch [1][1650/13219]	lr: 2.500e-03, eta: 3:44:26, time: 0.350, data_time: 0.038, memory: 4209, loss_rpn_cls: 0.1005, loss_rpn_bbox: 0.0920, loss_cls: 0.6269, acc: 80.1367, loss_bbox: 0.6074, loss_mask: 0.3516, loss: 1.7784
# 2021-11-22 18:40:29,731 - mmdet - INFO - Epoch [1][1660/13219]	lr: 2.500e-03, eta: 3:44:22, time: 0.355, data_time: 0.042, memory: 4209, loss_rpn_cls: 0.0533, loss_rpn_bbox: 0.0772, loss_cls: 0.5797, acc: 80.4785, loss_bbox: 0.5911, loss_mask: 0.3266, loss: 1.6279
# ...
# 2021-11-22 22:19:30,068 - mmdet - INFO - Epoch [3][12630/13219]	lr: 2.500e-03, eta: 0:03:26, time: 0.337, data_time: 0.031, memory: 4209, loss_rpn_cls: 0.0534, loss_rpn_bbox: 0.0701, loss_cls: 0.4896, acc: 83.2422, loss_bbox: 0.4673, loss_mask: 0.2909, loss: 1.3714
# 2021-11-22 22:19:33,553 - mmdet - INFO - Epoch [3][12640/13219]	lr: 2.500e-03, eta: 0:03:23, time: 0.349, data_time: 0.039, memory: 4209, loss_rpn_cls: 0.0517, loss_rpn_bbox: 0.0613, loss_cls: 0.4561, acc: 83.2129, loss_bbox: 0.4318, loss_mask: 0.2849, loss: 1.2858
# 2021-11-22 22:19:37,149 - mmdet - INFO - Epoch [3][12650/13219]	lr: 2.500e-03, eta: 0:03:19, time: 0.359, data_time: 0.041, memory: 4209, loss_rpn_cls: 0.0470, loss_rpn_bbox: 0.0773, loss_cls: 0.4498, acc: 82.8125, loss_bbox: 0.4697, loss_mask: 0.2623, loss: 1.3061
# 2021-11-22 22:19:40,599 - mmdet - INFO - Epoch [3][12660/13219]	lr: 2.500e-03, eta: 0:03:16, time: 0.345, data_time: 0.041, memory: 4209, loss_rpn_cls: 0.0535, loss_rpn_bbox: 0.0760, loss_cls: 0.5646, acc: 80.9863, loss_bbox: 0.5116, loss_mask: 0.3255, loss: 1.5312
# 2021-11-22 22:19:44,253 - mmdet - INFO - Epoch [3][12670/13219]	lr: 2.500e-03, eta: 0:03:12, time: 0.365, data_time: 0.046, memory: 4209, loss_rpn_cls: 0.0484, loss_rpn_bbox: 0.0758, loss_cls: 0.4334, acc: 83.7012, loss_bbox: 0.4483, loss_mask: 0.2589, loss: 1.2648
# 2021-11-22 22:19:47,849 - mmdet - INFO - Epoch [3][12680/13219]	lr: 2.500e-03, eta: 0:03:09, time: 0.360, data_time: 0.053, memory: 4209, loss_rpn_cls: 0.0644, loss_rpn_bbox: 0.0898, loss_cls: 0.5250, acc: 80.7227, loss_bbox: 0.5047, loss_mask: 0.2963, loss: 1.4801
# 2021-11-22 22:19:51,400 - mmdet - INFO - Epoch [3][12690/13219]	lr: 2.500e-03, eta: 0:03:05, time: 0.355, data_time: 0.047, memory: 4209, loss_rpn_cls: 0.0649, loss_rpn_bbox: 0.0797, loss_cls: 0.4655, acc: 82.6465, loss_bbox: 0.4680, loss_mask: 0.2926, loss: 1.3707
# 2021-11-22 22:19:55,054 - mmdet - INFO - Epoch [3][12700/13219]	lr: 2.500e-03, eta: 0:03:02, time: 0.365, data_time: 0.055, memory: 4209, loss_rpn_cls: 0.0776, loss_rpn_bbox: 0.0870, loss_cls: 0.5231, acc: 82.3340, loss_bbox: 0.5162, loss_mask: 0.3066, loss: 1.5105
# 2021-11-22 22:19:58,576 - mmdet - INFO - Epoch [3][12710/13219]	lr: 2.500e-03, eta: 0:02:58, time: 0.353, data_time: 0.036, memory: 4209, loss_rpn_cls: 0.0529, loss_rpn_bbox: 0.0692, loss_cls: 0.4659, acc: 83.2812, loss_bbox: 0.4850, loss_mask: 0.2789, loss: 1.3519
# 2021-11-22 22:20:02,160 - mmdet - INFO - Epoch [3][12720/13219]	lr: 2.500e-03, eta: 0:02:55, time: 0.358, data_time: 0.049, memory: 4209, loss_rpn_cls: 0.1088, loss_rpn_bbox: 0.0814, loss_cls: 0.4696, acc: 82.4219, loss_bbox: 0.4830, loss_mask: 0.2980, loss: 1.4409
# 2021-11-22 22:20:05,834 - mmdet - INFO - Epoch [3][12730/13219]	lr: 2.500e-03, eta: 0:02:51, time: 0.367, data_time: 0.059, memory: 4209, loss_rpn_cls: 0.0790, loss_rpn_bbox: 0.1020, loss_cls: 0.5122, acc: 81.0254, loss_bbox: 0.5122, loss_mask: 0.3006, loss: 1.5060
# 2021-11-22 22:20:09,394 - mmdet - INFO - Epoch [3][12740/13219]	lr: 2.500e-03, eta: 0:02:48, time: 0.356, data_time: 0.041, memory: 4209, loss_rpn_cls: 0.0677, loss_rpn_bbox: 0.0742, loss_cls: 0.5264, acc: 80.8691, loss_bbox: 0.5114, loss_mask: 0.2959, loss: 1.4756
# 2021-11-22 22:20:13,002 - mmdet - INFO - Epoch [3][12750/13219]	lr: 2.500e-03, eta: 0:02:44, time: 0.360, data_time: 0.042, memory: 4209, loss_rpn_cls: 0.0642, loss_rpn_bbox: 0.0842, loss_cls: 0.4937, acc: 81.2988, loss_bbox: 0.4676, loss_mask: 0.2831, loss: 1.3929
# 2021-11-22 22:20:16,525 - mmdet - INFO - Epoch [3][12760/13219]	lr: 2.500e-03, eta: 0:02:41, time: 0.353, data_time: 0.034, memory: 4209, loss_rpn_cls: 0.0730, loss_rpn_bbox: 0.0620, loss_cls: 0.4919, acc: 82.2559, loss_bbox: 0.4648, loss_mask: 0.2731, loss: 1.3648
# 2021-11-22 22:20:20,024 - mmdet - INFO - Epoch [3][12770/13219]	lr: 2.500e-03, eta: 0:02:37, time: 0.349, data_time: 0.039, memory: 4209, loss_rpn_cls: 0.0791, loss_rpn_bbox: 0.0723, loss_cls: 0.4904, acc: 82.6074, loss_bbox: 0.4916, loss_mask: 0.3022, loss: 1.4357
# 2021-11-22 22:20:23,531 - mmdet - INFO - Epoch [3][12780/13219]	lr: 2.500e-03, eta: 0:02:34, time: 0.351, data_time: 0.037, memory: 4209, loss_rpn_cls: 0.0461, loss_rpn_bbox: 0.0664, loss_cls: 0.4440, acc: 82.6855, loss_bbox: 0.4870, loss_mask: 0.2802, loss: 1.3238
# 2021-11-22 22:20:27,119 - mmdet - INFO - Epoch [3][12790/13219]	lr: 2.500e-03, eta: 0:02:30, time: 0.359, data_time: 0.047, memory: 4209, loss_rpn_cls: 0.0802, loss_rpn_bbox: 0.0804, loss_cls: 0.4759, acc: 81.9922, loss_bbox: 0.4528, loss_mask: 0.2921, loss: 1.3814
# 2021-11-22 22:20:30,711 - mmdet - INFO - Epoch [3][12800/13219]	lr: 2.500e-03, eta: 0:02:27, time: 0.359, data_time: 0.041, memory: 4209, loss_rpn_cls: 0.0488, loss_rpn_bbox: 0.0678, loss_cls: 0.4861, acc: 82.3340, loss_bbox: 0.4991, loss_mask: 0.2805, loss: 1.3823
# 2021-11-22 22:20:34,143 - mmdet - INFO - Epoch [3][12810/13219]	lr: 2.500e-03, eta: 0:02:23, time: 0.343, data_time: 0.034, memory: 4209, loss_rpn_cls: 0.0470, loss_rpn_bbox: 0.0598, loss_cls: 0.4858, acc: 83.2031, loss_bbox: 0.4693, loss_mask: 0.3115, loss: 1.3734
# 2021-11-22 22:20:37,649 - mmdet - INFO - Epoch [3][12820/13219]	lr: 2.500e-03, eta: 0:02:20, time: 0.351, data_time: 0.053, memory: 4209, loss_rpn_cls: 0.0625, loss_rpn_bbox: 0.0868, loss_cls: 0.4344, acc: 83.6719, loss_bbox: 0.4408, loss_mask: 0.2899, loss: 1.3145
# 2021-11-22 22:20:41,096 - mmdet - INFO - Epoch [3][12830/13219]	lr: 2.500e-03, eta: 0:02:16, time: 0.344, data_time: 0.044, memory: 4209, loss_rpn_cls: 0.0665, loss_rpn_bbox: 0.0807, loss_cls: 0.4880, acc: 81.8652, loss_bbox: 0.5107, loss_mask: 0.3004, loss: 1.4463
# 2021-11-22 22:20:44,671 - mmdet - INFO - Epoch [3][12840/13219]	lr: 2.500e-03, eta: 0:02:13, time: 0.358, data_time: 0.043, memory: 4209, loss_rpn_cls: 0.0572, loss_rpn_bbox: 0.0627, loss_cls: 0.4738, acc: 82.5195, loss_bbox: 0.4944, loss_mask: 0.2880, loss: 1.3761
# 2021-11-22 22:20:48,121 - mmdet - INFO - Epoch [3][12850/13219]	lr: 2.500e-03, eta: 0:02:09, time: 0.345, data_time: 0.035, memory: 4209, loss_rpn_cls: 0.0651, loss_rpn_bbox: 0.0660, loss_cls: 0.4639, acc: 82.6465, loss_bbox: 0.4713, loss_mask: 0.2927, loss: 1.3591
# 2021-11-22 22:20:51,741 - mmdet - INFO - Epoch [3][12860/13219]	lr: 2.500e-03, eta: 0:02:06, time: 0.362, data_time: 0.049, memory: 4209, loss_rpn_cls: 0.0981, loss_rpn_bbox: 0.0987, loss_cls: 0.4913, acc: 81.4160, loss_bbox: 0.4735, loss_mask: 0.3050, loss: 1.4666
# 2021-11-22 22:20:55,292 - mmdet - INFO - Epoch [3][12870/13219]	lr: 2.500e-03, eta: 0:02:02, time: 0.355, data_time: 0.038, memory: 4209, loss_rpn_cls: 0.0612, loss_rpn_bbox: 0.0645, loss_cls: 0.4604, acc: 82.2266, loss_bbox: 0.4664, loss_mask: 0.2826, loss: 1.3351
# 2021-11-22 22:20:58,774 - mmdet - INFO - Epoch [3][12880/13219]	lr: 2.500e-03, eta: 0:01:59, time: 0.349, data_time: 0.043, memory: 4209, loss_rpn_cls: 0.0529, loss_rpn_bbox: 0.0819, loss_cls: 0.4497, acc: 83.1055, loss_bbox: 0.4616, loss_mask: 0.2932, loss: 1.3393
# 2021-11-22 22:21:02,411 - mmdet - INFO - Epoch [3][12890/13219]	lr: 2.500e-03, eta: 0:01:55, time: 0.364, data_time: 0.049, memory: 4209, loss_rpn_cls: 0.0547, loss_rpn_bbox: 0.0765, loss_cls: 0.4689, acc: 82.0020, loss_bbox: 0.4634, loss_mask: 0.2711, loss: 1.3346
# 2021-11-22 22:21:05,878 - mmdet - INFO - Epoch [3][12900/13219]	lr: 2.500e-03, eta: 0:01:52, time: 0.346, data_time: 0.039, memory: 4209, loss_rpn_cls: 0.0680, loss_rpn_bbox: 0.0760, loss_cls: 0.4948, acc: 82.4219, loss_bbox: 0.4464, loss_mask: 0.2812, loss: 1.3664
# 2021-11-22 22:21:09,359 - mmdet - INFO - Epoch [3][12910/13219]	lr: 2.500e-03, eta: 0:01:48, time: 0.348, data_time: 0.042, memory: 4209, loss_rpn_cls: 0.0743, loss_rpn_bbox: 0.0825, loss_cls: 0.4690, acc: 82.3438, loss_bbox: 0.4911, loss_mask: 0.2936, loss: 1.4105
# 2021-11-22 22:21:12,841 - mmdet - INFO - Epoch [3][12920/13219]	lr: 2.500e-03, eta: 0:01:45, time: 0.348, data_time: 0.037, memory: 4209, loss_rpn_cls: 0.0501, loss_rpn_bbox: 0.0667, loss_cls: 0.4515, acc: 82.6172, loss_bbox: 0.4717, loss_mask: 0.2780, loss: 1.3180
# 2021-11-22 22:21:16,491 - mmdet - INFO - Epoch [3][12930/13219]	lr: 2.500e-03, eta: 0:01:41, time: 0.365, data_time: 0.050, memory: 4209, loss_rpn_cls: 0.0801, loss_rpn_bbox: 0.0886, loss_cls: 0.5252, acc: 80.4883, loss_bbox: 0.5408, loss_mask: 0.3146, loss: 1.5492
# libpng warning: Ignoring iCCP chunk with declared size = 3757432833 and actual length = 19492
# 2021-11-22 22:21:20,115 - mmdet - INFO - Epoch [3][12940/13219]	lr: 2.500e-03, eta: 0:01:38, time: 0.362, data_time: 0.040, memory: 4209, loss_rpn_cls: 0.0536, loss_rpn_bbox: 0.0610, loss_cls: 0.4247, acc: 84.5801, loss_bbox: 0.4533, loss_mask: 0.2853, loss: 1.2780
# 2021-11-22 22:21:23,738 - mmdet - INFO - Epoch [3][12950/13219]	lr: 2.500e-03, eta: 0:01:34, time: 0.362, data_time: 0.039, memory: 4209, loss_rpn_cls: 0.0451, loss_rpn_bbox: 0.0705, loss_cls: 0.5224, acc: 82.1582, loss_bbox: 0.5057, loss_mask: 0.2942, loss: 1.4379
# 2021-11-22 22:21:27,186 - mmdet - INFO - Epoch [3][12960/13219]	lr: 2.500e-03, eta: 0:01:30, time: 0.345, data_time: 0.036, memory: 4209, loss_rpn_cls: 0.0406, loss_rpn_bbox: 0.0641, loss_cls: 0.4361, acc: 83.2227, loss_bbox: 0.4517, loss_mask: 0.2762, loss: 1.2687
# 2021-11-22 22:21:30,782 - mmdet - INFO - Epoch [3][12970/13219]	lr: 2.500e-03, eta: 0:01:27, time: 0.359, data_time: 0.045, memory: 4209, loss_rpn_cls: 0.0538, loss_rpn_bbox: 0.0772, loss_cls: 0.4579, acc: 82.8809, loss_bbox: 0.4594, loss_mask: 0.2822, loss: 1.3306
# 2021-11-22 22:21:34,309 - mmdet - INFO - Epoch [3][12980/13219]	lr: 2.500e-03, eta: 0:01:23, time: 0.353, data_time: 0.041, memory: 4209, loss_rpn_cls: 0.0618, loss_rpn_bbox: 0.0744, loss_cls: 0.5091, acc: 82.1582, loss_bbox: 0.4921, loss_mask: 0.2984, loss: 1.4357
# 2021-11-22 22:21:37,870 - mmdet - INFO - Epoch [3][12990/13219]	lr: 2.500e-03, eta: 0:01:20, time: 0.356, data_time: 0.046, memory: 4209, loss_rpn_cls: 0.0412, loss_rpn_bbox: 0.0855, loss_cls: 0.5137, acc: 80.7715, loss_bbox: 0.5144, loss_mask: 0.3187, loss: 1.4735
# 2021-11-22 22:21:41,282 - mmdet - INFO - Epoch [3][13000/13219]	lr: 2.500e-03, eta: 0:01:16, time: 0.341, data_time: 0.032, memory: 4209, loss_rpn_cls: 0.0512, loss_rpn_bbox: 0.0746, loss_cls: 0.4836, acc: 81.6797, loss_bbox: 0.4946, loss_mask: 0.2973, loss: 1.4013
# 2021-11-22 22:21:44,831 - mmdet - INFO - Epoch [3][13010/13219]	lr: 2.500e-03, eta: 0:01:13, time: 0.355, data_time: 0.046, memory: 4209, loss_rpn_cls: 0.0612, loss_rpn_bbox: 0.0739, loss_cls: 0.5002, acc: 82.5293, loss_bbox: 0.4762, loss_mask: 0.3039, loss: 1.4154
# 2021-11-22 22:21:48,309 - mmdet - INFO - Epoch [3][13020/13219]	lr: 2.500e-03, eta: 0:01:09, time: 0.347, data_time: 0.036, memory: 4209, loss_rpn_cls: 0.0457, loss_rpn_bbox: 0.0629, loss_cls: 0.4419, acc: 82.3047, loss_bbox: 0.4679, loss_mask: 0.2610, loss: 1.2794
# 2021-11-22 22:21:52,102 - mmdet - INFO - Epoch [3][13030/13219]	lr: 2.500e-03, eta: 0:01:06, time: 0.380, data_time: 0.056, memory: 4209, loss_rpn_cls: 0.0361, loss_rpn_bbox: 0.0758, loss_cls: 0.4494, acc: 83.2227, loss_bbox: 0.4622, loss_mask: 0.2888, loss: 1.3123
# 2021-11-22 22:21:55,646 - mmdet - INFO - Epoch [3][13040/13219]	lr: 2.500e-03, eta: 0:01:02, time: 0.354, data_time: 0.039, memory: 4209, loss_rpn_cls: 0.0464, loss_rpn_bbox: 0.0713, loss_cls: 0.4971, acc: 82.6758, loss_bbox: 0.4878, loss_mask: 0.2931, loss: 1.3956
# 2021-11-22 22:21:59,233 - mmdet - INFO - Epoch [3][13050/13219]	lr: 2.500e-03, eta: 0:00:59, time: 0.360, data_time: 0.045, memory: 4209, loss_rpn_cls: 0.0520, loss_rpn_bbox: 0.0727, loss_cls: 0.4916, acc: 82.1777, loss_bbox: 0.4746, loss_mask: 0.3010, loss: 1.3920
# 2021-11-22 22:22:02,819 - mmdet - INFO - Epoch [3][13060/13219]	lr: 2.500e-03, eta: 0:00:55, time: 0.357, data_time: 0.040, memory: 4209, loss_rpn_cls: 0.0488, loss_rpn_bbox: 0.0756, loss_cls: 0.4913, acc: 82.6562, loss_bbox: 0.5010, loss_mask: 0.3009, loss: 1.4177
# 2021-11-22 22:22:06,319 - mmdet - INFO - Epoch [3][13070/13219]	lr: 2.500e-03, eta: 0:00:52, time: 0.351, data_time: 0.040, memory: 4209, loss_rpn_cls: 0.0778, loss_rpn_bbox: 0.0748, loss_cls: 0.5332, acc: 79.9512, loss_bbox: 0.4859, loss_mask: 0.2936, loss: 1.4652
# 2021-11-22 22:22:09,870 - mmdet - INFO - Epoch [3][13080/13219]	lr: 2.500e-03, eta: 0:00:48, time: 0.355, data_time: 0.039, memory: 4209, loss_rpn_cls: 0.0609, loss_rpn_bbox: 0.0758, loss_cls: 0.4976, acc: 81.7871, loss_bbox: 0.4883, loss_mask: 0.2877, loss: 1.4103
# 2021-11-22 22:22:13,387 - mmdet - INFO - Epoch [3][13090/13219]	lr: 2.500e-03, eta: 0:00:45, time: 0.352, data_time: 0.039, memory: 4209, loss_rpn_cls: 0.0333, loss_rpn_bbox: 0.0621, loss_cls: 0.4663, acc: 82.5000, loss_bbox: 0.4842, loss_mask: 0.2862, loss: 1.3321
# 2021-11-22 22:22:17,080 - mmdet - INFO - Epoch [3][13100/13219]	lr: 2.500e-03, eta: 0:00:41, time: 0.369, data_time: 0.054, memory: 4209, loss_rpn_cls: 0.0684, loss_rpn_bbox: 0.0944, loss_cls: 0.4534, acc: 83.1738, loss_bbox: 0.4741, loss_mask: 0.2707, loss: 1.3610
# 2021-11-22 22:22:20,514 - mmdet - INFO - Epoch [3][13110/13219]	lr: 2.500e-03, eta: 0:00:38, time: 0.343, data_time: 0.027, memory: 4209, loss_rpn_cls: 0.0362, loss_rpn_bbox: 0.0499, loss_cls: 0.4534, acc: 83.2031, loss_bbox: 0.4888, loss_mask: 0.2882, loss: 1.3166
# 2021-11-22 22:22:23,982 - mmdet - INFO - Epoch [3][13120/13219]	lr: 2.500e-03, eta: 0:00:34, time: 0.347, data_time: 0.031, memory: 4209, loss_rpn_cls: 0.0615, loss_rpn_bbox: 0.0714, loss_cls: 0.4594, acc: 83.6230, loss_bbox: 0.4561, loss_mask: 0.2946, loss: 1.3431
# 2021-11-22 22:22:27,482 - mmdet - INFO - Epoch [3][13130/13219]	lr: 2.500e-03, eta: 0:00:31, time: 0.350, data_time: 0.036, memory: 4209, loss_rpn_cls: 0.0515, loss_rpn_bbox: 0.0623, loss_cls: 0.4645, acc: 82.5195, loss_bbox: 0.4769, loss_mask: 0.2931, loss: 1.3484
# 2021-11-22 22:22:31,129 - mmdet - INFO - Epoch [3][13140/13219]	lr: 2.500e-03, eta: 0:00:27, time: 0.365, data_time: 0.058, memory: 4209, loss_rpn_cls: 0.0804, loss_rpn_bbox: 0.0957, loss_cls: 0.5050, acc: 80.4688, loss_bbox: 0.5094, loss_mask: 0.3007, loss: 1.4912
# 2021-11-22 22:22:34,664 - mmdet - INFO - Epoch [3][13150/13219]	lr: 2.500e-03, eta: 0:00:24, time: 0.354, data_time: 0.045, memory: 4209, loss_rpn_cls: 0.0334, loss_rpn_bbox: 0.0607, loss_cls: 0.4807, acc: 81.8262, loss_bbox: 0.4813, loss_mask: 0.2997, loss: 1.3557
# 2021-11-22 22:22:38,163 - mmdet - INFO - Epoch [3][13160/13219]	lr: 2.500e-03, eta: 0:00:20, time: 0.350, data_time: 0.034, memory: 4209, loss_rpn_cls: 0.0545, loss_rpn_bbox: 0.0695, loss_cls: 0.4931, acc: 81.4453, loss_bbox: 0.5038, loss_mask: 0.3032, loss: 1.4242
# 2021-11-22 22:22:41,608 - mmdet - INFO - Epoch [3][13170/13219]	lr: 2.500e-03, eta: 0:00:17, time: 0.344, data_time: 0.035, memory: 4209, loss_rpn_cls: 0.0487, loss_rpn_bbox: 0.0679, loss_cls: 0.4406, acc: 82.5977, loss_bbox: 0.4873, loss_mask: 0.2813, loss: 1.3257
# 2021-11-22 22:22:45,165 - mmdet - INFO - Epoch [3][13180/13219]	lr: 2.500e-03, eta: 0:00:13, time: 0.356, data_time: 0.041, memory: 4209, loss_rpn_cls: 0.1200, loss_rpn_bbox: 0.0771, loss_cls: 0.4493, acc: 84.1113, loss_bbox: 0.4584, loss_mask: 0.2774, loss: 1.3822
# 2021-11-22 22:22:48,745 - mmdet - INFO - Epoch [3][13190/13219]	lr: 2.500e-03, eta: 0:00:10, time: 0.358, data_time: 0.044, memory: 4209, loss_rpn_cls: 0.0827, loss_rpn_bbox: 0.0897, loss_cls: 0.5105, acc: 81.3379, loss_bbox: 0.4931, loss_mask: 0.2798, loss: 1.4558
# 2021-11-22 22:22:52,438 - mmdet - INFO - Epoch [3][13200/13219]	lr: 2.500e-03, eta: 0:00:06, time: 0.370, data_time: 0.051, memory: 4209, loss_rpn_cls: 0.0646, loss_rpn_bbox: 0.0790, loss_cls: 0.4786, acc: 81.4551, loss_bbox: 0.5185, loss_mask: 0.3078, loss: 1.4485
# 2021-11-22 22:22:56,004 - mmdet - INFO - Epoch [3][13210/13219]	lr: 2.500e-03, eta: 0:00:03, time: 0.357, data_time: 0.046, memory: 4209, loss_rpn_cls: 0.0498, loss_rpn_bbox: 0.0820, loss_cls: 0.4776, acc: 81.8359, loss_bbox: 0.4867, loss_mask: 0.2899, loss: 1.3859
# 2021-11-22 22:22:59,371 - mmdet - INFO - Saving checkpoint at 3 epochs

# %%
from mmdet.apis import inference_detector, show_result_pyplot

checkpoint_file = './tutorial_exps/epoch_50.pth'

# checkpoint 저장된 model 파일을 이용하여 모델을 생성, 이때 Config는 위에서 update된 config 사용. 
model_ckpt = init_detector(cfg, checkpoint_file, device='cuda:0')
# Out:
# load checkpoint from local path: ./tutorial_exps/epoch_50.pth

# %%
import cv2
# val_img_name = val_df['image_name'].iloc[0]
# print(val_img_name)

# BGR Image 사용 

img_arr = cv2.imread('/home/seonghwan/PyTorch-Simple-MaskRCNN/heroes_data/train_dataset/2014_val=mask/COCO_val2014_000000001000.png')
model_ckpt.cfg = cfg

results = inference_detector(model_ckpt, img_arr)
show_result_pyplot(model_ckpt, img_arr, results, score_thr=0.1)
# Out:
# /home/seonghwan/mmdetection/mmdet/datasets/utils.py:65: UserWarning: "ImageToTensor" pipeline is replaced by "DefaultFormatBundle" for batch inference. It is recommended to manually replace it in the test data pipeline in your config file.
#   warnings.warn(
# /home/seonghwan/anaconda3/envs/mask_rcnn_ver2/lib/python3.8/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# /home/seonghwan/mmdetection/mmdet/core/visualization/image.py:183: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
import numpy as np
labels_to_names_seq = [{1:'body'},
                    {2:'right_hand'},
                    {3:'left_hand'},
                    {4:'left_foot'},
                    {5:'right_foot'},
                    {6:'right_thigh'},
                    {7:'left_thigh'},
                    {8:'right_calf'},
                    {9:'left_calf'},
                    {10:'left_arm'},
                    {11:'right_arm'},
                    {12:'left_forearm'},
                    {13:'right_forearm'},
                    {14:'head'}]
  
COLORS = list(
    [[0, 255, 0],
     [0, 0, 255],
     [255, 0, 0],
     [0, 255, 255],
     [255, 255, 0],
     [255, 0, 255],
     [80, 70, 180],
     [250, 80, 190],
     [245, 145, 50],
     [70, 150, 250],
     [70, 0 ,0],
     [141, 200 ,250],
     [250, 70 ,255],
     [255, 70 , 70],
     [111, 1 ,25],
     [111, 70 ,255],
     [210, 52 ,177],
])

# %%
# model과 원본 이미지 array, filtering할 기준 class confidence score를 인자로 가지는 inference 시각화용 함수 생성. 
# 이미 inference 시 mask boolean값이 들어오므로 mask_threshold 값을 필요하지 않음. 
def get_detected_img(model, img_array,  score_threshold=0.3, draw_box=True, is_print=True):
  # 인자로 들어온 image_array를 복사. 
  draw_img = img_array.copy()
  bbox_color=(0, 255, 0)
  text_color=(0, 0, 255)

  # model과 image array를 입력 인자로 inference detection 수행하고 결과를 results로 받음.  
  results = inference_detector(model, img_array)
  bbox_results = results[0]
  seg_results = results[1]

  # results 리스트를 loop를 돌면서 개별 2차원 array들을 추출하고 이를 기반으로 이미지 시각화 
  # results 리스트의 위치 index가 매핑된 Class id. 여기서는 result_ind가 class id
  # 개별 2차원 array에 오브젝트별 좌표와 class confidence score 값을 가짐. 
  for result_ind, bbox_result in enumerate(bbox_results):
    # 개별 2차원 array의 row size가 0 이면 해당 Class id로 값이 없으므로 다음 loop로 진행. 
    if len(bbox_result) == 0:
      continue
    
    mask_array_list = seg_results[result_ind]
    
    # 해당 클래스 별로 Detect된 여러개의 오브젝트 정보가 2차원 array에 담겨 있으며, 이 2차원 array를 row수만큼 iteration해서 개별 오브젝트의 좌표값 추출. 
    for i in range(len(bbox_result)):
      # 좌상단, 우하단 좌표 추출. 
      if bbox_result[i, 4] > score_threshold:
        left = int(bbox_result[i, 0])
        top = int(bbox_result[i, 1])
        right = int(bbox_result[i, 2])
        bottom = int(bbox_result[i, 3])
        caption = "{}: {:.4f}".format(labels_to_names_seq[result_ind], bbox_result[i, 4])
        if draw_box:
          cv2.rectangle(draw_img, (left, top), (right, bottom), color=bbox_color, thickness=2)
          cv2.putText(draw_img, caption, (int(left), int(top - 7)), cv2.FONT_HERSHEY_SIMPLEX, 0.37, text_color, 1)
        # masking 시각화 적용. class_mask_array는 image 크기 shape의  True/False값을 가지는 2차원 array
        class_mask_array = mask_array_list[i]
        # 원본 image array에서 mask가 True인 영역만 별도 추출. 
        masked_roi = draw_img[class_mask_array]
        
        #color를 임의 지정
        # color_index = np.random.randint(0, len(COLORS)-1)
        # color를 class별로 지정
        color_index = result_ind % len(COLORS)
        color = COLORS[color_index]

        # apply_mask()함수를 적용시 수행 시간이 상대적으로 오래 걸림. 
        #draw_img = apply_mask(draw_img, class_mask_array, color, alpha=0.4)
        # 원본 이미지의 masking 될 영역에 mask를 특정 투명 컬러로 적용
        draw_img[class_mask_array] = ([0.3*color[0], 0.3*color[1], 0.3*color[2]] + 0.6 * masked_roi).astype(np.uint8)
        
        if is_print:
          print(caption)
  
  return draw_img

# %%
from PIL import Image
cv2.imwrite('image/baps_image.png',img_arr)
# Out:
# True

# %%
cv2.imwrite('image/segmentation.png',detected_img)
# Out:
# True

# %%
# Line extraction

# %%
# inference mask detected 된 이미지 보기
import matplotlib.pyplot as plt
from glob import glob 
from tqdm import tqdm
from PIL import Image
image_list = []
path = glob('/media/seonghwan/1.8T_Backup_HDD/Label/2017/6/*.png')

for i in tqdm(path):
    
    
    img = cv2.imread(i)
    image_list.append(img)
# Out:
# 100%|██████████| 614/614 [00:31<00:00, 19.20it/s]

# %%
img_arr = image_list[20]
detected_img = get_detected_img(model_ckpt, img_arr,  score_threshold=0.48, draw_box=True, is_print=True)
detected_img = cv2.cvtColor(detected_img, cv2.COLOR_BGR2RGB)
cv2.imwrite('result_test/seg1.png',detected_img)
# Out:
# {1: 'body'}: 0.9965
# {3: 'left_hand'}: 0.7329
# {3: 'left_hand'}: 0.7213
# {4: 'left_foot'}: 0.5125
# {4: 'left_foot'}: 0.4902
# {5: 'right_foot'}: 0.4921
# {6: 'right_thigh'}: 0.5178
# {6: 'right_thigh'}: 0.4858
# {7: 'left_thigh'}: 0.5298
# {7: 'left_thigh'}: 0.5246
# {8: 'right_calf'}: 0.5031
# {8: 'right_calf'}: 0.4953
# {9: 'left_calf'}: 0.5227
# {9: 'left_calf'}: 0.5185
# {10: 'left_arm'}: 0.6430
# {10: 'left_arm'}: 0.5905
# {12: 'left_forearm'}: 0.5924
# {12: 'left_forearm'}: 0.5474
# {13: 'right_forearm'}: 0.4855
# {13: 'right_forearm'}: 0.4806
# {14: 'head'}: 0.9666
# True
